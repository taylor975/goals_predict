# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Predicting NHL Goal Scoring - Data Collection </h1></div>

# %% [markdown]
# ***BrainStation Data Science Capstone Project*** <br/>
# ***Author:***  &ensp;    **Taylor Gallivan** <br/>
# ***Date:*** &ensp; **Sep-Nov 2023**

# %% [markdown]
# ### Introduction
#
# ***This notebook is soley for the purposes of data collection.  Please see notebook `API_Debugging.ipynb` for code breakdown.***
#
# In this notebook, the NHL API was called in increments of roughly 5,000 player IDs.  The upper and lower boundaries of which player IDs to include in the iteration process was sort of a moving goal post as I became more familiar with the inner machinations of the API.  It appears that new player IDs are assigned in chronological order (i.e., the more recent a player is, the higher their ID), but for older players they appear to have been added in batches, in alphabetical order.  As such, an 8th API call was added to capture the beginning of a specific batch of players - some of whom played within the era that is to be included in analysis and modeling.
#
# Players were called by their ID Number, as stored in the API.  A partial list of player IDs was retrieved from https://hockey-statistics.com/, which helped shape the structuring of the API calls.
#
# A second collection DataFrame was instantiated prior to Call 4 as a precautionary measure.  After all calls were completed, the two collection DataFrames were merged into one.  See below for the call breakdowns.
#
# Below are the call breakdowns:
#  - Call 1 IDs:  8445000 - 8450000  <-- starts at 'Dave Andreychuk'
#  - Call 2 IDs:  8450000 - 8455000
#  - Call 3 IDs:  8455000 - 8460000
#  - Call 4 IDs:  8460000 - 8465000  <-- new DataFrame started here
#  - Call 5 IDs:  8465000 - 8470000
#  - Call 6 IDs:  8470000 - 8475000
#  - Call 7 IDs:  8475000 - 8482246  <-- ends at 'Artem Zub'
#  - Call 8 IDs:  8444894 - 8445000  <-- added to original DataFrame to round out the lower bound of player IDs

# %%
import requests
import json
import pandas as pd
from datetime import datetime
import numpy as np

# %% [markdown]
# ### Call 1 - DONE
# Player IDs:  8445000 - 8450000

# %%
# First 5000 entries.
df_main = pd.DataFrame()
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8445000, 8450000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            # evaluate response code, pass if 500
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                df_splits = (pd.json_normalize(splits, sep = "_" )
                             .query('league_name == "National Hockey League"')
                            )
                            
                if df_splits.shape[0] >= 3:
                    df_splits['player_id'] = player['id'][0]
                    df_splits['name'] = player['fullName'][0]
                    df_splits['position_code'] = player['primaryPosition.code'][0]
                    df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                    total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                    filtered_total_games = total_games[total_games['stat_games'] > 180]
                    
                    if not filtered_total_games.empty:
                        df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                        df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                        df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                        
                        df_splits['weight'] = player['weight'][0]
                        df_splits['height'] = player['height'][0]
                        df_splits['shot_dir'] = player['shootsCatches'][0]
                        df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                        df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                        df_splits['age'] = df_splits['age'].astype(int)
                        df_splits['position_name'] = player['primaryPosition.name'][0]
                        df_splits['position_type'] = player['primaryPosition.type'][0]
                        df_splits['birth_country'] = player['birthCountry'][0]
                        df_splits['nationality'] = player['nationality'][0]
                        
                        # concatenate the DF for the current player, to the main DF
                        df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                    else:
                        pass        
                else:
                    pass
            else:
                pass
        else:
            pass
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:233, in Scope.resolve(self, key, is_local)
#     232 if self.has_resolvers:
# --> 233     return self.resolvers[key]
#     235 # if we're here that means that we have no locals and we also have
#     236 # no resolvers
#
# File ~\anaconda3\Lib\collections\__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# File ~\anaconda3\Lib\collections\__init__.py:998, in ChainMap.__missing__(self, key)
#     997 def __missing__(self, key):
# --> 998     raise KeyError(key)
#
# KeyError: 'league_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     240 try:
#     241     # last ditch effort we look in temporaries
#     242     # these are created when parsing indexing expressions
#     243     # e.g., df[df > 0]
# --> 244     return self.temps[key]
#     245 except KeyError as err:
#
# KeyError: 'league_name'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[4], line 24
#      20 content = json.loads(response.content)['stats']
#      21 splits = content[0]['splits']
#      23 df_splits = (pd.json_normalize(splits, sep = "_" )
# ---> 24              .query('league_name == "National Hockey League"')
#      25             )
#      27 if df_splits.shape[0] >= 3:
#      28     df_splits['player_id'] = player['id'][0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4440, in DataFrame.query(self, expr, inplace, **kwargs)
#    4438 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4439 kwargs["target"] = None
# -> 4440 res = self.eval(expr, **kwargs)
#    4442 try:
#    4443     result = self.loc[res]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4566, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4563     kwargs["target"] = self
#    4564 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4566 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:535, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:455, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     453 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     454     if left is None:
# --> 455         left = self.visit(node.left, side="left")
#     456     if right is None:
#     457         right = self.visit(node.right, side="right")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:548, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     547 def visit_Name(self, node, **kwargs):
# --> 548     return self.term_type(node.id, self.env, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:86, in Term.__init__(self, name, env, side, encoding)
#      84 tname = str(name)
#      85 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86 self._value = self._resolve_name()
#      87 self.encoding = encoding
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:110, in Term._resolve_name(self)
#     105 if local_name in self.env.scope and isinstance(
#     106     self.env.scope[local_name], type
#     107 ):
#     108     is_local = False
# --> 110 res = self.env.resolve(local_name, is_local=is_local)
#     111 self.update(res)
#     113 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:246, in Scope.resolve(self, key, is_local)
#     244     return self.temps[key]
#     245 except KeyError as err:
# --> 246     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'league_name' is not defined

# %%
# Before running another pass here, let's rearrange some columns for readability

id_df = df_main[['player_id', 'name', 'position_code']]

# Sanity Check
id_df
# Out:
#       player_id             name position_code
# 0       8445000  Dave Andreychuk             L
# 1       8445000  Dave Andreychuk             L
# 2       8445000  Dave Andreychuk             L
# 3       8445000  Dave Andreychuk             L
# 4       8445000  Dave Andreychuk             L
# ...         ...              ...           ...
# 1032    8445400     Curt Bennett             R
# 1033    8445400     Curt Bennett             R
# 1034    8445400     Curt Bennett             R
# 1035    8445400     Curt Bennett             R
# 1036    8445400     Curt Bennett             R
#
# [1037 rows x 3 columns]

# %%
# reform the dataframe
df_main = id_df.join(df_main.drop(columns=['player_id', 'name', 'position_code']))
df_main
# Out:
#       player_id             name position_code    season  sequenceNumber  \
# 0       8445000  Dave Andreychuk             L  19821983               1
# 1       8445000  Dave Andreychuk             L  19831984               1
# 2       8445000  Dave Andreychuk             L  19841985               1
# 3       8445000  Dave Andreychuk             L  19851986               1
# 4       8445000  Dave Andreychuk             L  19861987               1
# ...         ...              ...           ...       ...             ...
# 1032    8445400     Curt Bennett             R  19761977               1
# 1033    8445400     Curt Bennett             R  19771978               1
# 1034    8445400     Curt Bennett             R  19771978               2
# 1035    8445400     Curt Bennett             R  19781979               1
# 1036    8445400     Curt Bennett             R  19791980               1
#
#       stat_assists  stat_goals  stat_games  stat_points        team_name  ...  \
# 0             23.0        14.0          43         37.0   Buffalo Sabres  ...
# 1             42.0        38.0          78         80.0   Buffalo Sabres  ...
# 2             30.0        31.0          64         61.0   Buffalo Sabres  ...
# 3             51.0        36.0          80         87.0   Buffalo Sabres  ...
# 4             48.0        25.0          77         73.0   Buffalo Sabres  ...
# ...            ...         ...         ...          ...              ...  ...
# 1032          25.0        22.0          76         47.0   Atlanta Flames  ...
# 1033           7.0         3.0          25         10.0   Atlanta Flames  ...
# 1034          17.0         7.0          50         24.0  St. Louis Blues  ...
# 1035          19.0        14.0          74         33.0  St. Louis Blues  ...
# 1036           3.0         1.0          21          4.0   Atlanta Flames  ...
#
#      season_end weight height  shot_dir birth_date  age  position_name  \
# 0          1983    225  6' 4"         R 1963-09-29   19      Left Wing
# 1          1984    225  6' 4"         R 1963-09-29   20      Left Wing
# 2          1985    225  6' 4"         R 1963-09-29   21      Left Wing
# 3          1986    225  6' 4"         R 1963-09-29   22      Left Wing
# 4          1987    225  6' 4"         R 1963-09-29   23      Left Wing
# ...         ...    ...    ...       ...        ...  ...            ...
# 1032       1977    195  6' 3"         L 1948-03-27   28     Right Wing
# 1033       1978    195  6' 3"         L 1948-03-27   29     Right Wing
# 1034       1978    195  6' 3"         L 1948-03-27   29     Right Wing
# 1035       1979    195  6' 3"         L 1948-03-27   30     Right Wing
# 1036       1980    195  6' 3"         L 1948-03-27   31     Right Wing
#
#       position_type  birth_country  nationality
# 0           Forward            CAN          CAN
# 1           Forward            CAN          CAN
# 2           Forward            CAN          CAN
# 3           Forward            CAN          CAN
# 4           Forward            CAN          CAN
# ...             ...            ...          ...
# 1032        Forward            CAN          CAN
# 1033        Forward            CAN          CAN
# 1034        Forward            CAN          CAN
# 1035        Forward            CAN          CAN
# 1036        Forward            CAN          CAN
#
# [1037 rows x 46 columns]

# %%
# Restart at 8445401

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8445401, 8450000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            # evaluate response code, pass if 500
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['weight'] = player['weight'][0]
                            df_splits['height'] = player['height'][0]
                            df_splits['shot_dir'] = player['shootsCatches'][0]
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shootsCatches'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 45
#      43 df_splits['weight'] = player['weight'][0]
#      44 df_splits['height'] = player['height'][0]
# ---> 45 df_splits['shot_dir'] = player['shootsCatches'][0]
#      46 df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
#      47 df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'shootsCatches'

# %%
# Get Dave Lewis stats --> 8448811

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
num = 8448811

people_url = f'{base_url}{num}'
response = requests.get(people_url)
   
if response.status_code != 404:
    suggestions = json.loads(response.content)['people']
    player = (pd.json_normalize(suggestions))
    
    if player['primaryPosition.code'][0] != 'G':
        stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
        response = requests.get(stats_url)
           
        if response.status_code != 500:
            content = json.loads(response.content)['stats']
            splits = content[0]['splits']
               
            if not splits:
                pass
            else:
                df_splits = (pd.json_normalize(splits, sep = "_" )
                            .query('league_name == "National Hockey League"')
                            )
                                    
                if df_splits.shape[0] >= 3:
                    df_splits['player_id'] = player['id'][0]
                    df_splits['name'] = player['fullName'][0]
                    df_splits['position_code'] = player['primaryPosition.code'][0]
                    df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                    total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                    filtered_total_games = total_games[total_games['stat_games'] > 180]
                    
                    if not filtered_total_games.empty:
                        df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                        df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                        df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                                
                        df_splits['weight'] = player['weight'][0]
                        df_splits['height'] = player['height'][0]
                        df_splits['shot_dir'] = 'L'
                        df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                        df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                        df_splits['age'] = df_splits['age'].astype(int)
                        df_splits['position_name'] = player['primaryPosition.name'][0]
                        df_splits['position_type'] = player['primaryPosition.type'][0]
                        df_splits['birth_country'] = player['birthCountry'][0]
                        df_splits['nationality'] = player['nationality'][0]
                                
                        df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                    else:
                        pass        
                else:
                    pass
        else:
            pass
    else:
        pass
else:
    pass

# %%
df_main
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 11608    8448811       Dave Lewis             D  19831984               1
# 11609    8448811       Dave Lewis             D  19841985               1
# 11610    8448811       Dave Lewis             D  19851986               1
# 11611    8448811       Dave Lewis             D  19861987               1
# 11612    8448811       Dave Lewis             D  19871988               1
#
#        stat_assists  stat_goals  stat_games  stat_points          team_name  \
# 0              23.0        14.0          43         37.0     Buffalo Sabres
# 1              42.0        38.0          78         80.0     Buffalo Sabres
# 2              30.0        31.0          64         61.0     Buffalo Sabres
# 3              51.0        36.0          80         87.0     Buffalo Sabres
# 4              48.0        25.0          77         73.0     Buffalo Sabres
# ...             ...         ...         ...          ...                ...
# 11608           5.0         2.0          66          7.0  New Jersey Devils
# 11609           9.0         3.0          74         12.0  New Jersey Devils
# 11610          15.0         0.0          69         15.0  New Jersey Devils
# 11611           5.0         2.0          58          7.0  Detroit Red Wings
# 11612           0.0         0.0           6          0.0  Detroit Red Wings
#
#        ... season_end weight height  shot_dir birth_date  age  position_name  \
# 0      ...       1983    225  6' 4"         R 1963-09-29   19      Left Wing
# 1      ...       1984    225  6' 4"         R 1963-09-29   20      Left Wing
# 2      ...       1985    225  6' 4"         R 1963-09-29   21      Left Wing
# 3      ...       1986    225  6' 4"         R 1963-09-29   22      Left Wing
# 4      ...       1987    225  6' 4"         R 1963-09-29   23      Left Wing
# ...    ...        ...    ...    ...       ...        ...  ...            ...
# 11608  ...       1984    205  6' 2"         L 1953-07-03   30     Defenseman
# 11609  ...       1985    205  6' 2"         L 1953-07-03   31     Defenseman
# 11610  ...       1986    205  6' 2"         L 1953-07-03   32     Defenseman
# 11611  ...       1987    205  6' 2"         L 1953-07-03   33     Defenseman
# 11612  ...       1988    205  6' 2"         L 1953-07-03   34     Defenseman
#
#        position_type  birth_country  nationality
# 0            Forward            CAN          CAN
# 1            Forward            CAN          CAN
# 2            Forward            CAN          CAN
# 3            Forward            CAN          CAN
# 4            Forward            CAN          CAN
# ...              ...            ...          ...
# 11608     Defenseman            CAN          CAN
# 11609     Defenseman            CAN          CAN
# 11610     Defenseman            CAN          CAN
# 11611     Defenseman            CAN          CAN
# 11612     Defenseman            CAN          CAN
#
# [11613 rows x 46 columns]

# %%
# Restart at 8448813

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8448813, 8450000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            # evaluate response code, pass if 500
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['weight'] = player['weight'][0]
                            df_splits['height'] = player['height'][0]
                            df_splits['shot_dir'] = player['shootsCatches'][0]
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shootsCatches'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 45
#      43 df_splits['weight'] = player['weight'][0]
#      44 df_splits['height'] = player['height'][0]
# ---> 45 df_splits['shot_dir'] = player['shootsCatches'][0]
#      46 df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
#      47 df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'shootsCatches'

# %% [markdown]
# Evidently there are multiple players for which a shooting direction is not recorded in the NHL's database.  Add new conditionals to set up default values for missing info in player bios.

# %%
# Restart at 8448846

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8448846, 8450000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
df_main
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 15049    8449973     Eddie Olczyk             R  19961997               1
# 15050    8449973     Eddie Olczyk             R  19961997               2
# 15051    8449973     Eddie Olczyk             R  19971998               1
# 15052    8449973     Eddie Olczyk             R  19981999               1
# 15053    8449973     Eddie Olczyk             R  19992000               1
#
#        stat_assists  stat_goals  stat_games  stat_points            team_name  \
# 0              23.0        14.0          43         37.0       Buffalo Sabres
# 1              42.0        38.0          78         80.0       Buffalo Sabres
# 2              30.0        31.0          64         61.0       Buffalo Sabres
# 3              51.0        36.0          80         87.0       Buffalo Sabres
# 4              48.0        25.0          77         73.0       Buffalo Sabres
# ...             ...         ...         ...          ...                  ...
# 15049          23.0        21.0          67         44.0    Los Angeles Kings
# 15050           7.0         4.0          12         11.0  Pittsburgh Penguins
# 15051          11.0        11.0          56         22.0  Pittsburgh Penguins
# 15052          15.0        10.0          61         25.0   Chicago Blackhawks
# 15053           2.0         2.0          33          4.0   Chicago Blackhawks
#
#        ... season_end weight height  shot_dir birth_date  age  position_name  \
# 0      ...       1983    225  6' 4"         R 1963-09-29   19      Left Wing
# 1      ...       1984    225  6' 4"         R 1963-09-29   20      Left Wing
# 2      ...       1985    225  6' 4"         R 1963-09-29   21      Left Wing
# 3      ...       1986    225  6' 4"         R 1963-09-29   22      Left Wing
# 4      ...       1987    225  6' 4"         R 1963-09-29   23      Left Wing
# ...    ...        ...    ...    ...       ...        ...  ...            ...
# 15049  ...       1997    207  6' 1"         L 1966-08-16   30     Right Wing
# 15050  ...       1997    207  6' 1"         L 1966-08-16   30     Right Wing
# 15051  ...       1998    207  6' 1"         L 1966-08-16   31     Right Wing
# 15052  ...       1999    207  6' 1"         L 1966-08-16   32     Right Wing
# 15053  ...       2000    207  6' 1"         L 1966-08-16   33     Right Wing
#
#        position_type  birth_country  nationality
# 0            Forward            CAN          CAN
# 1            Forward            CAN          CAN
# 2            Forward            CAN          CAN
# 3            Forward            CAN          CAN
# 4            Forward            CAN          CAN
# ...              ...            ...          ...
# 15049        Forward            USA          USA
# 15050        Forward            USA          USA
# 15051        Forward            USA          USA
# 15052        Forward            USA          USA
# 15053        Forward            USA          USA
#
# [15054 rows x 46 columns]

# %%
print(df_main[df_main['name'] == 'Lyle Odelein'])
# Out:
#        player_id          name position_code    season  sequenceNumber  \
# 14966    8449957  Lyle Odelein             D  19891990               1
# 14967    8449957  Lyle Odelein             D  19901991               1
# 14968    8449957  Lyle Odelein             D  19911992               1
# 14969    8449957  Lyle Odelein             D  19921993               1
# 14970    8449957  Lyle Odelein             D  19931994               1
# 14971    8449957  Lyle Odelein             D  19941995               1
# 14972    8449957  Lyle Odelein             D  19951996               1
# 14973    8449957  Lyle Odelein             D  19961997               1
# 14974    8449957  Lyle Odelein             D  19971998               1
# 14975    8449957  Lyle Odelein             D  19981999               1
# 14976    8449957  Lyle Odelein             D  19992000               1
# 14977    8449957  Lyle Odelein             D  19992000               2
# 14978    8449957  Lyle Odelein             D  20002001               1
# 14979    8449957  Lyle Odelein             D  20012002               1
# 14980    8449957  Lyle Odelein             D  20012002               2
# 14981    8449957  Lyle Odelein             D  20022003               1
# 14982    8449957  Lyle Odelein             D  20022003               2
# 14983    8449957  Lyle Odelein             D  20032004               1
# 14984    8449957  Lyle Odelein             D  20052006               1
#
#        stat_assists  stat_goals  stat_games  stat_points  \
# 14966           2.0         0.0           8          2.0
# 14967           2.0         0.0          52          2.0
# 14968           7.0         1.0          71          8.0
# 14969          14.0         2.0          83         16.0
# 14970          29.0        11.0          79         40.0
# 14971           7.0         3.0          48         10.0
# 14972          14.0         3.0          79         17.0
# 14973          13.0         3.0          79         16.0
# 14974          19.0         4.0          79         23.0
# 14975          26.0         5.0          70         31.0
# 14976          15.0         1.0          57         16.0
# 14977           7.0         1.0          16          8.0
# 14978          14.0         3.0          81         17.0
# 14979          14.0         2.0          65         16.0
# 14980           2.0         0.0          12          2.0
# 14981           4.0         7.0          65         11.0
# 14982           0.0         0.0           3          0.0
# 14983          12.0         4.0          82         16.0
# 14984           1.0         0.0          27          1.0
#
#                    team_name  ... season_end weight height  shot_dir  \
# 14966     Montréal Canadiens  ...       1990    212  6' 0"         L
# 14967     Montréal Canadiens  ...       1991    212  6' 0"         L
# 14968     Montréal Canadiens  ...       1992    212  6' 0"         L
# 14969     Montréal Canadiens  ...       1993    212  6' 0"         L
# 14970     Montréal Canadiens  ...       1994    212  6' 0"         L
# 14971     Montréal Canadiens  ...       1995    212  6' 0"         L
# 14972     Montréal Canadiens  ...       1996    212  6' 0"         L
# 14973      New Jersey Devils  ...       1997    212  6' 0"         L
# 14974      New Jersey Devils  ...       1998    212  6' 0"         L
# 14975      New Jersey Devils  ...       1999    212  6' 0"         L
# 14976      New Jersey Devils  ...       2000    212  6' 0"         L
# 14977        Phoenix Coyotes  ...       2000    212  6' 0"         L
# 14978  Columbus Blue Jackets  ...       2001    212  6' 0"         L
# 14979  Columbus Blue Jackets  ...       2002    212  6' 0"         L
# 14980     Chicago Blackhawks  ...       2002    212  6' 0"         L
# 14981     Chicago Blackhawks  ...       2003    212  6' 0"         L
# 14982           Dallas Stars  ...       2003    212  6' 0"         L
# 14983       Florida Panthers  ...       2004    212  6' 0"         L
# 14984    Pittsburgh Penguins  ...       2006    212  6' 0"         L
#
#       birth_date  age  position_name  position_type  birth_country  \
# 14966 1968-07-21   21     Defenseman     Defenseman            CAN
# 14967 1968-07-21   22     Defenseman     Defenseman            CAN
# 14968 1968-07-21   23     Defenseman     Defenseman            CAN
# 14969 1968-07-21   24     Defenseman     Defenseman            CAN
# 14970 1968-07-21   25     Defenseman     Defenseman            CAN
# 14971 1968-07-21   26     Defenseman     Defenseman            CAN
# 14972 1968-07-21   27     Defenseman     Defenseman            CAN
# 14973 1968-07-21   28     Defenseman     Defenseman            CAN
# 14974 1968-07-21   29     Defenseman     Defenseman            CAN
# 14975 1968-07-21   30     Defenseman     Defenseman            CAN
# 14976 1968-07-21   31     Defenseman     Defenseman            CAN
# 14977 1968-07-21   31     Defenseman     Defenseman            CAN
# 14978 1968-07-21   32     Defenseman     Defenseman            CAN
# 14979 1968-07-21   33     Defenseman     Defenseman            CAN
# 14980 1968-07-21   33     Defenseman     Defenseman            CAN
# 14981 1968-07-21   34     Defenseman     Defenseman            CAN
# 14982 1968-07-21   34     Defenseman     Defenseman            CAN
# 14983 1968-07-21   35     Defenseman     Defenseman            CAN
# 14984 1968-07-21   37     Defenseman     Defenseman            CAN
#
#        nationality
# 14966          CAN
# 14967          CAN
# 14968          CAN
# 14969          CAN
# 14970          CAN
# 14971          CAN
# 14972          CAN
# 14973          CAN
# 14974          CAN
# 14975          CAN
# 14976          CAN
# 14977          CAN
# 14978          CAN
# 14979          CAN
# 14980          CAN
# 14981          CAN
# 14982          CAN
# 14983          CAN
# 14984          CAN
#
# [19 rows x 46 columns]

# %% [markdown]
# ### Call 2 - DONE
# Player IDs:  8450000 - 8455000

# %%
# Call 2

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8450000, 8455000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass
# Out:
# KeyboardInterrupt

# %% [markdown]
# ### Call 3 - DONE
# Player IDs:  8455000 - 8460000

# %%
# Call 3

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8455000, 8460000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
df_main
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 22988    8444998       Ace Bailey             R  19291930               1
# 22989    8444998       Ace Bailey             R  19301931               1
# 22990    8444998       Ace Bailey             R  19311932               1
# 22991    8444998       Ace Bailey             R  19321933               1
# 22992    8444998       Ace Bailey             R  19331934               1
#
#        stat_assists  stat_goals  stat_games  stat_points            team_name  \
# 0              23.0        14.0          43         37.0       Buffalo Sabres
# 1              42.0        38.0          78         80.0       Buffalo Sabres
# 2              30.0        31.0          64         61.0       Buffalo Sabres
# 3              51.0        36.0          80         87.0       Buffalo Sabres
# 4              48.0        25.0          77         73.0       Buffalo Sabres
# ...             ...         ...         ...          ...                  ...
# 22988          21.0        22.0          43         43.0  Toronto Maple Leafs
# 22989          19.0        23.0          40         42.0  Toronto Maple Leafs
# 22990           5.0         8.0          44         13.0  Toronto Maple Leafs
# 22991           8.0        10.0          47         18.0  Toronto Maple Leafs
# 22992           3.0         2.0          13          5.0  Toronto Maple Leafs
#
#        ... season_end weight  height  shot_dir           birth_date  age  \
# 0      ...       1983    225   6' 4"         R           1963-09-29   19
# 1      ...       1984    225   6' 4"         R           1963-09-29   20
# 2      ...       1985    225   6' 4"         R           1963-09-29   21
# 3      ...       1986    225   6' 4"         R           1963-09-29   22
# 4      ...       1987    225   6' 4"         R           1963-09-29   23
# ...    ...        ...    ...     ...       ...                  ...  ...
# 22988  ...       1930    160  5' 10"         R  1903-07-03 00:00:00   26
# 22989  ...       1931    160  5' 10"         R  1903-07-03 00:00:00   27
# 22990  ...       1932    160  5' 10"         R  1903-07-03 00:00:00   28
# 22991  ...       1933    160  5' 10"         R  1903-07-03 00:00:00   29
# 22992  ...       1934    160  5' 10"         R  1903-07-03 00:00:00   30
#
#        position_name  position_type  birth_country  nationality
# 0          Left Wing        Forward            CAN          CAN
# 1          Left Wing        Forward            CAN          CAN
# 2          Left Wing        Forward            CAN          CAN
# 3          Left Wing        Forward            CAN          CAN
# 4          Left Wing        Forward            CAN          CAN
# ...              ...            ...            ...          ...
# 22988     Right Wing        Forward            CAN          CAN
# 22989     Right Wing        Forward            CAN          CAN
# 22990     Right Wing        Forward            CAN          CAN
# 22991     Right Wing        Forward            CAN          CAN
# 22992     Right Wing        Forward            CAN          CAN
#
# [22993 rows x 46 columns]

# %%
# save df_main
df_main.to_csv('df_main1.csv', index=False)

# %% [markdown]
# ### Call 4 - DONE
# Player IDs:  8460000 - 8465000 <br>
# Starting a new DataFrame here as a precaution.  Will merge the two larger DataFrames once data collection is done.

# %%
# Call 4

df_main2 = pd.DataFrame()
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8460000, 8465000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main2 = pd.concat([df_main2, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
df_main2
# Out:
#         season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 0     19961997               1            NaN             0           0
# 1     19971998               1        1110:09            12           4
# 2     19981999               1         425:18             2           4
# 3     19992000               1         637:05             6           3
# 4     20002001               1         785:35             7           5
# ...        ...             ...            ...           ...         ...
# 1617  20012002               1         718:47            10           9
# 1618  20022003               1        1287:37            24          16
# 1619  20032004               1        1232:19            17          13
# 1620  20052006               1        1140:35            20          20
# 1621  20062007               1        1135:45            11          12
#
#       stat_pim  stat_games stat_penaltyMinutes  stat_points  \
# 0          4.0          21                   4            0
# 1         20.0          62                  20           16
# 2         14.0          31                  14            6
# 3         24.0          61                  24            9
# 4         26.0          64                  26           12
# ...        ...         ...                 ...          ...
# 1617       8.0          53                   8           19
# 1618      30.0          82                  30           40
# 1619      30.0          72                  30           30
# 1620      50.0          73                  50           40
# 1621      70.0          79                  70           23
#
#                team_name  ... season_end birth_date age  position_name  \
# 0     Colorado Avalanche  ...       1997 1973-10-29  22      Left Wing
# 1     Colorado Avalanche  ...       1998 1973-10-29  23      Left Wing
# 2     Colorado Avalanche  ...       1999 1973-10-29  24      Left Wing
# 3     Colorado Avalanche  ...       2000 1973-10-29  25      Left Wing
# 4     Colorado Avalanche  ...       2001 1973-10-29  26      Left Wing
# ...                  ...  ...        ...        ...  ..            ...
# 1617  Montréal Canadiens  ...       2002 1978-03-18  23         Center
# 1618  Montréal Canadiens  ...       2003 1978-03-18  24         Center
# 1619  Montréal Canadiens  ...       2004 1978-03-18  25         Center
# 1620  Montréal Canadiens  ...       2006 1978-03-18  27         Center
# 1621   Vancouver Canucks  ...       2007 1978-03-18  28         Center
#
#       position_type  birth_country  nationality  weight  height  shot_dir
# 0           Forward            CAN          CAN     197   6' 2"         L
# 1           Forward            CAN          CAN     197   6' 2"         L
# 2           Forward            CAN          CAN     197   6' 2"         L
# 3           Forward            CAN          CAN     197   6' 2"         L
# 4           Forward            CAN          CAN     197   6' 2"         L
# ...             ...            ...          ...     ...     ...       ...
# 1617        Forward            CZE          CZE     209   6' 0"         L
# 1618        Forward            CZE          CZE     209   6' 0"         L
# 1619        Forward            CZE          CZE     209   6' 0"         L
# 1620        Forward            CZE          CZE     209   6' 0"         L
# 1621        Forward            CZE          CZE     209   6' 0"         L
#
# [1622 rows x 46 columns]

# %%
# print Derek Morris stats
print(df_main2[df_main2['player_id'] == 8464966])
# Out:
#         season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 1436  19971998               1        1589:14            20           9
# 1437  19981999               1        1472:05            27           7
# 1438  19992000               1        1937:51            29           9
# 1439  20002001               1        1318:02            23           5
# 1440  20012002               1        1504:47            30           4
# 1441  20022003               1        1786:33            37          11
# 1442  20032004               1        1441:21            22           6
# 1443  20032004               2         350:29             4           0
# 1444  20052006               1        1105:37            21           6
# 1445  20062007               1        1680:16            19           6
# 1446  20072008               1        1780:32            17           8
# 1447  20082009               1        1212:28             7           5
# 1448  20082009               2         354:10             8           0
# 1449  20092010               1        1276:03            22           3
# 1450  20092010               2         353:44             3           1
# 1451  20102011               1        1621:30            11           5
# 1452  20112012               1        1120:21             9           2
# 1453  20122013               1         834:27            11           0
# 1454  20132014               1        1225:16            12           5
#
#       stat_pim  stat_games stat_penaltyMinutes  stat_points  \
# 1436      88.0          82                  88           29
# 1437      73.0          71                  73           34
# 1438      80.0          78                  80           38
# 1439      56.0          51                  56           28
# 1440      88.0          61                  88           34
# 1441      68.0          75                  68           48
# 1442      47.0          69                  47           28
# 1443       2.0          14                   2            4
# 1444      54.0          53                  54           27
# 1445     115.0          82                 115           25
# 1446      83.0          82                  83           25
# 1447      24.0          57                  24           12
# 1448      16.0          18                  16            8
# 1449      26.0          58                  26           25
# 1450      11.0          18                  11            4
# 1451      58.0          77                  58           16
# 1452      38.0          59                  38           11
# 1453      36.0          39                  36           11
# 1454      41.0          63                  41           17
#
#                team_name  ... season_end birth_date age  position_name  \
# 1436      Calgary Flames  ...       1998 1978-08-24  19     Defenseman
# 1437      Calgary Flames  ...       1999 1978-08-24  20     Defenseman
# 1438      Calgary Flames  ...       2000 1978-08-24  21     Defenseman
# 1439      Calgary Flames  ...       2001 1978-08-24  22     Defenseman
# 1440      Calgary Flames  ...       2002 1978-08-24  23     Defenseman
# 1441  Colorado Avalanche  ...       2003 1978-08-24  24     Defenseman
# 1442  Colorado Avalanche  ...       2004 1978-08-24  25     Defenseman
# 1443     Phoenix Coyotes  ...       2004 1978-08-24  25     Defenseman
# 1444     Phoenix Coyotes  ...       2006 1978-08-24  27     Defenseman
# 1445     Phoenix Coyotes  ...       2007 1978-08-24  28     Defenseman
# 1446     Phoenix Coyotes  ...       2008 1978-08-24  29     Defenseman
# 1447     Phoenix Coyotes  ...       2009 1978-08-24  30     Defenseman
# 1448    New York Rangers  ...       2009 1978-08-24  30     Defenseman
# 1449       Boston Bruins  ...       2010 1978-08-24  31     Defenseman
# 1450     Phoenix Coyotes  ...       2010 1978-08-24  31     Defenseman
# 1451     Phoenix Coyotes  ...       2011 1978-08-24  32     Defenseman
# 1452     Phoenix Coyotes  ...       2012 1978-08-24  33     Defenseman
# 1453     Phoenix Coyotes  ...       2013 1978-08-24  34     Defenseman
# 1454     Phoenix Coyotes  ...       2014 1978-08-24  35     Defenseman
#
#       position_type  birth_country  nationality  weight  height  shot_dir
# 1436     Defenseman            CAN          CAN     210   6' 0"         R
# 1437     Defenseman            CAN          CAN     210   6' 0"         R
# 1438     Defenseman            CAN          CAN     210   6' 0"         R
# 1439     Defenseman            CAN          CAN     210   6' 0"         R
# 1440     Defenseman            CAN          CAN     210   6' 0"         R
# 1441     Defenseman            CAN          CAN     210   6' 0"         R
# 1442     Defenseman            CAN          CAN     210   6' 0"         R
# 1443     Defenseman            CAN          CAN     210   6' 0"         R
# 1444     Defenseman            CAN          CAN     210   6' 0"         R
# 1445     Defenseman            CAN          CAN     210   6' 0"         R
# 1446     Defenseman            CAN          CAN     210   6' 0"         R
# 1447     Defenseman            CAN          CAN     210   6' 0"         R
# 1448     Defenseman            CAN          CAN     210   6' 0"         R
# 1449     Defenseman            CAN          CAN     210   6' 0"         R
# 1450     Defenseman            CAN          CAN     210   6' 0"         R
# 1451     Defenseman            CAN          CAN     210   6' 0"         R
# 1452     Defenseman            CAN          CAN     210   6' 0"         R
# 1453     Defenseman            CAN          CAN     210   6' 0"         R
# 1454     Defenseman            CAN          CAN     210   6' 0"         R
#
# [19 rows x 46 columns]

# %% [markdown]
# ### Call 5 - DONE
# Player IDs:  8465000 - 8470000 <br>
# Results added to second DataFrame (`df_main2`).

# %%
# Call 5

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8465000, 8470000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main2 = pd.concat([df_main2, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %% [markdown]
# ### Call 6 - DONE
# Player IDs:  8470000 - 8475000 <br>
# Results added to second DataFrame (`df_main2`).

# %%
# Call 6 

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8470000, 8475000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main2 = pd.concat([df_main2, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
df_main2
# Out:
#          season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 0      19961997               1            NaN           0.0         0.0
# 1      19971998               1        1110:09          12.0         4.0
# 2      19981999               1         425:18           2.0         4.0
# 3      19992000               1         637:05           6.0         3.0
# 4      20002001               1         785:35           7.0         5.0
# ...         ...             ...            ...           ...         ...
# 10066  20192020               1        1161:48          30.0        29.0
# 10067  20202021               1         783:20          19.0        17.0
# 10068  20212022               1        1141:49          20.0        15.0
# 10069  20222023               1        1050:08          20.0        14.0
# 10070  20232024               1          85:05           1.0         0.0
#
#        stat_pim  stat_games stat_penaltyMinutes  stat_points  \
# 0           4.0          21                   4            0
# 1          20.0          62                  20           16
# 2          14.0          31                  14            6
# 3          24.0          61                  24            9
# 4          26.0          64                  26           12
# ...         ...         ...                 ...          ...
# 10066      28.0          69                  28           59
# 10067      10.0          52                  10           36
# 10068      32.0          67                  32           35
# 10069      28.0          67                  28           34
# 10070       2.0           5                   2            1
#
#                 team_name  ... season_end birth_date age  position_name  \
# 0      Colorado Avalanche  ...       1997 1973-10-29  22      Left Wing
# 1      Colorado Avalanche  ...       1998 1973-10-29  23      Left Wing
# 2      Colorado Avalanche  ...       1999 1973-10-29  24      Left Wing
# 3      Colorado Avalanche  ...       2000 1973-10-29  25      Left Wing
# 4      Colorado Avalanche  ...       2001 1973-10-29  26      Left Wing
# ...                   ...  ...        ...        ...  ..            ...
# 10066    Florida Panthers  ...       2020 1989-11-24  29         Center
# 10067     St. Louis Blues  ...       2021 1989-11-24  30         Center
# 10068  Montréal Canadiens  ...       2022 1989-11-24  31         Center
# 10069  Montréal Canadiens  ...       2023 1989-11-24  32         Center
# 10070     San Jose Sharks  ...       2024 1989-11-24  33         Center
#
#        position_type  birth_country  nationality  weight  height  shot_dir
# 0            Forward            CAN          CAN     197   6' 2"         L
# 1            Forward            CAN          CAN     197   6' 2"         L
# 2            Forward            CAN          CAN     197   6' 2"         L
# 3            Forward            CAN          CAN     197   6' 2"         L
# 4            Forward            CAN          CAN     197   6' 2"         L
# ...              ...            ...          ...     ...     ...       ...
# 10066        Forward            CAN          CAN     190   6' 0"         L
# 10067        Forward            CAN          CAN     190   6' 0"         L
# 10068        Forward            CAN          CAN     190   6' 0"         L
# 10069        Forward            CAN          CAN     190   6' 0"         L
# 10070        Forward            CAN          CAN     190   6' 0"         L
#
# [10071 rows x 46 columns]

# %% [markdown]
# ### Call 7 - DONE
# Player IDs:  8475000 - 8482246 <br>
# Results added to second DataFrame (`df_main2`).

# %%
# save df_main
df_main2.to_csv('df_main2.csv', index=False)

# %%
# Call 7

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8475000, 8482246)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main2 = pd.concat([df_main2, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
df_main2
# Out:
#          season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 0      19961997               1            NaN           0.0         0.0
# 1      19971998               1        1110:09          12.0         4.0
# 2      19981999               1         425:18           2.0         4.0
# 3      19992000               1         637:05           6.0         3.0
# 4      20002001               1         785:35           7.0         5.0
# ...         ...             ...            ...           ...         ...
# 14797  20232024               1         103:16           4.0         2.0
# 14798  20202021               1         863:58          11.0         3.0
# 14799  20212022               1        1704:14          16.0         6.0
# 14800  20222023               1        1073:25           7.0         3.0
# 14801  20232024               1          71:49           2.0         1.0
#
#        stat_pim  stat_games stat_penaltyMinutes  stat_points  \
# 0           4.0          21                   4            0
# 1          20.0          62                  20           16
# 2          14.0          31                  14            6
# 3          24.0          61                  24            9
# 4          26.0          64                  26           12
# ...         ...         ...                 ...          ...
# 14797       8.0           5                   8            6
# 14798      26.0          47                  26           14
# 14799      60.0          81                  60           22
# 14800      39.0          53                  39           10
# 14801       4.0           4                   4            3
#
#                 team_name  ... season_end birth_date age  position_name  \
# 0      Colorado Avalanche  ...       1997 1973-10-29  22      Left Wing
# 1      Colorado Avalanche  ...       1998 1973-10-29  23      Left Wing
# 2      Colorado Avalanche  ...       1999 1973-10-29  24      Left Wing
# 3      Colorado Avalanche  ...       2000 1973-10-29  25      Left Wing
# 4      Colorado Avalanche  ...       2001 1973-10-29  26      Left Wing
# ...                   ...  ...        ...        ...  ..            ...
# 14797     Ottawa Senators  ...       2024 2002-01-15  21         Center
# 14798     Ottawa Senators  ...       2021 1995-10-03  25     Defenseman
# 14799     Ottawa Senators  ...       2022 1995-10-03  26     Defenseman
# 14800     Ottawa Senators  ...       2023 1995-10-03  27     Defenseman
# 14801     Ottawa Senators  ...       2024 1995-10-03  28     Defenseman
#
#        position_type  birth_country  nationality  weight  height  shot_dir
# 0            Forward            CAN          CAN     197   6' 2"         L
# 1            Forward            CAN          CAN     197   6' 2"         L
# 2            Forward            CAN          CAN     197   6' 2"         L
# 3            Forward            CAN          CAN     197   6' 2"         L
# 4            Forward            CAN          CAN     197   6' 2"         L
# ...              ...            ...          ...     ...     ...       ...
# 14797        Forward            DEU          DEU     197   6' 0"         L
# 14798     Defenseman            RUS          RUS     204   6' 3"         R
# 14799     Defenseman            RUS          RUS     204   6' 3"         R
# 14800     Defenseman            RUS          RUS     204   6' 3"         R
# 14801     Defenseman            RUS          RUS     204   6' 3"         R
#
# [14802 rows x 46 columns]

# %%
# save df_main
df_main2.to_csv('df_main2.csv', index=False)

# %% [markdown]
# ### Call 8 - DONE
#
# We will add in one more call to make sure we have all players of interest (i.e., those that played at least 3 seasons after the 1978-1979 season). <br>
# This call is waaaay too large - earliest player of interest is Greg Adams - 8444894
# Player IDs:  8444894 - 8445000 <br>
# Load in original Dataframe

# %%
df_main = pd.read_csv('df_main.csv')

# %%
df_main
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 22623    8459687     Scott Nichol             C  20122013               1
# 22624    8459700     Hans Jonsson             D  19992000               1
# 22625    8459700     Hans Jonsson             D  20002001               1
# 22626    8459700     Hans Jonsson             D  20012002               1
# 22627    8459700     Hans Jonsson             D  20022003               1
#
#        stat_assists  stat_goals  stat_games  stat_points            team_name  \
# 0              23.0        14.0          43         37.0       Buffalo Sabres
# 1              42.0        38.0          78         80.0       Buffalo Sabres
# 2              30.0        31.0          64         61.0       Buffalo Sabres
# 3              51.0        36.0          80         87.0       Buffalo Sabres
# 4              48.0        25.0          77         73.0       Buffalo Sabres
# ...             ...         ...         ...          ...                  ...
# 22623           0.0         1.0          30          1.0      St. Louis Blues
# 22624          11.0         3.0          68         14.0  Pittsburgh Penguins
# 22625          18.0         4.0          58         22.0  Pittsburgh Penguins
# 22626           5.0         2.0          53          7.0  Pittsburgh Penguins
# 22627           4.0         1.0          63          5.0  Pittsburgh Penguins
#
#        ... season_end weight height  shot_dir  birth_date  age  position_name  \
# 0      ...       1983    225  6' 4"         R  1963-09-29   19      Left Wing
# 1      ...       1984    225  6' 4"         R  1963-09-29   20      Left Wing
# 2      ...       1985    225  6' 4"         R  1963-09-29   21      Left Wing
# 3      ...       1986    225  6' 4"         R  1963-09-29   22      Left Wing
# 4      ...       1987    225  6' 4"         R  1963-09-29   23      Left Wing
# ...    ...        ...    ...    ...       ...         ...  ...            ...
# 22623  ...       2013    179  5' 8"         R  1974-12-31   37         Center
# 22624  ...       2000    176  6' 1"         L  1973-08-02   26     Defenseman
# 22625  ...       2001    176  6' 1"         L  1973-08-02   27     Defenseman
# 22626  ...       2002    176  6' 1"         L  1973-08-02   28     Defenseman
# 22627  ...       2003    176  6' 1"         L  1973-08-02   29     Defenseman
#
#        position_type  birth_country  nationality
# 0            Forward            CAN          CAN
# 1            Forward            CAN          CAN
# 2            Forward            CAN          CAN
# 3            Forward            CAN          CAN
# 4            Forward            CAN          CAN
# ...              ...            ...          ...
# 22623        Forward            CAN          CAN
# 22624     Defenseman            SWE          SWE
# 22625     Defenseman            SWE          SWE
# 22626     Defenseman            SWE          SWE
# 22627     Defenseman            SWE          SWE
#
# [22628 rows x 46 columns]

# %%
# Call 8

base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8444894, 8445000)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                if not splits:
                    pass
                else:
                    df_splits = (pd.json_normalize(splits, sep = "_" )
                                 .query('league_name == "National Hockey League"')
                                )
                                
                    if df_splits.shape[0] >= 3:
                        df_splits['player_id'] = player['id'][0]
                        df_splits['name'] = player['fullName'][0]
                        df_splits['position_code'] = player['primaryPosition.code'][0]
                        df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                        total_games = df_splits.groupby(['player_id', 'name',])['stat_games'].sum().reset_index()
                        filtered_total_games = total_games[total_games['stat_games'] > 180]
                        
                        if not filtered_total_games.empty:
                            df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                            df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                            df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                            
                            df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                            df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                            df_splits['age'] = df_splits['age'].astype(int)
                            df_splits['position_name'] = player['primaryPosition.name'][0]
                            df_splits['position_type'] = player['primaryPosition.type'][0]
                            df_splits['birth_country'] = player['birthCountry'][0]
                            df_splits['nationality'] = player['nationality'][0]
                            
                            # conditionals to pass default values where missing
                            if 'weight' not in player:
                                df_splits['weight'] = 0
                            else:
                                df_splits['weight'] = player['weight'][0]
                                
                            if 'height' not in player:
                                df_splits['height'] = 'unknown'
                            else:
                                df_splits['height'] = player['height'][0]
                            
                            if 'shootsCatches' not in player:
                                df_splits['shot_dir'] = 'unknown'
                            else:
                                df_splits['shot_dir'] = player['shootsCatches'][0]
                                
                            df_main = pd.concat([df_main, df_splits], sort=False).reset_index(drop=True)
                        else:
                            pass        
                    else:
                        pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
df_main
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 22988    8444998       Ace Bailey             R  19291930               1
# 22989    8444998       Ace Bailey             R  19301931               1
# 22990    8444998       Ace Bailey             R  19311932               1
# 22991    8444998       Ace Bailey             R  19321933               1
# 22992    8444998       Ace Bailey             R  19331934               1
#
#        stat_assists  stat_goals  stat_games  stat_points            team_name  \
# 0              23.0        14.0          43         37.0       Buffalo Sabres
# 1              42.0        38.0          78         80.0       Buffalo Sabres
# 2              30.0        31.0          64         61.0       Buffalo Sabres
# 3              51.0        36.0          80         87.0       Buffalo Sabres
# 4              48.0        25.0          77         73.0       Buffalo Sabres
# ...             ...         ...         ...          ...                  ...
# 22988          21.0        22.0          43         43.0  Toronto Maple Leafs
# 22989          19.0        23.0          40         42.0  Toronto Maple Leafs
# 22990           5.0         8.0          44         13.0  Toronto Maple Leafs
# 22991           8.0        10.0          47         18.0  Toronto Maple Leafs
# 22992           3.0         2.0          13          5.0  Toronto Maple Leafs
#
#        ... season_end weight  height  shot_dir           birth_date  age  \
# 0      ...       1983    225   6' 4"         R           1963-09-29   19
# 1      ...       1984    225   6' 4"         R           1963-09-29   20
# 2      ...       1985    225   6' 4"         R           1963-09-29   21
# 3      ...       1986    225   6' 4"         R           1963-09-29   22
# 4      ...       1987    225   6' 4"         R           1963-09-29   23
# ...    ...        ...    ...     ...       ...                  ...  ...
# 22988  ...       1930    160  5' 10"         R  1903-07-03 00:00:00   26
# 22989  ...       1931    160  5' 10"         R  1903-07-03 00:00:00   27
# 22990  ...       1932    160  5' 10"         R  1903-07-03 00:00:00   28
# 22991  ...       1933    160  5' 10"         R  1903-07-03 00:00:00   29
# 22992  ...       1934    160  5' 10"         R  1903-07-03 00:00:00   30
#
#        position_name  position_type  birth_country  nationality
# 0          Left Wing        Forward            CAN          CAN
# 1          Left Wing        Forward            CAN          CAN
# 2          Left Wing        Forward            CAN          CAN
# 3          Left Wing        Forward            CAN          CAN
# 4          Left Wing        Forward            CAN          CAN
# ...              ...            ...            ...          ...
# 22988     Right Wing        Forward            CAN          CAN
# 22989     Right Wing        Forward            CAN          CAN
# 22990     Right Wing        Forward            CAN          CAN
# 22991     Right Wing        Forward            CAN          CAN
# 22992     Right Wing        Forward            CAN          CAN
#
# [22993 rows x 46 columns]

# %% [markdown]
# ### Combining DataFrames
#
# Now we need to concatenate the three data frames into a single one.  Before doing so, I am checking for duplicates

# %%
# Combine df_main and df_main2

df_main_total = pd.concat([df_main, df_main2], sort=False).reset_index(drop=True)

# %%
df_main_total
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 37790    8482116      Tim Stützle             C  20232024               1
# 37791    8482245        Artem Zub             D  20202021               1
# 37792    8482245        Artem Zub             D  20212022               1
# 37793    8482245        Artem Zub             D  20222023               1
# 37794    8482245        Artem Zub             D  20232024               1
#
#        stat_assists  stat_goals  stat_games  stat_points        team_name  \
# 0              23.0        14.0          43         37.0   Buffalo Sabres
# 1              42.0        38.0          78         80.0   Buffalo Sabres
# 2              30.0        31.0          64         61.0   Buffalo Sabres
# 3              51.0        36.0          80         87.0   Buffalo Sabres
# 4              48.0        25.0          77         73.0   Buffalo Sabres
# ...             ...         ...         ...          ...              ...
# 37790           4.0         2.0           5          6.0  Ottawa Senators
# 37791          11.0         3.0          47         14.0  Ottawa Senators
# 37792          16.0         6.0          81         22.0  Ottawa Senators
# 37793           7.0         3.0          53         10.0  Ottawa Senators
# 37794           2.0         1.0           4          3.0  Ottawa Senators
#
#        ... season_end weight height  shot_dir           birth_date  age  \
# 0      ...       1983    225  6' 4"         R           1963-09-29   19
# 1      ...       1984    225  6' 4"         R           1963-09-29   20
# 2      ...       1985    225  6' 4"         R           1963-09-29   21
# 3      ...       1986    225  6' 4"         R           1963-09-29   22
# 4      ...       1987    225  6' 4"         R           1963-09-29   23
# ...    ...        ...    ...    ...       ...                  ...  ...
# 37790  ...       2024    197  6' 0"         L  2002-01-15 00:00:00   21
# 37791  ...       2021    204  6' 3"         R  1995-10-03 00:00:00   25
# 37792  ...       2022    204  6' 3"         R  1995-10-03 00:00:00   26
# 37793  ...       2023    204  6' 3"         R  1995-10-03 00:00:00   27
# 37794  ...       2024    204  6' 3"         R  1995-10-03 00:00:00   28
#
#        position_name  position_type  birth_country  nationality
# 0          Left Wing        Forward            CAN          CAN
# 1          Left Wing        Forward            CAN          CAN
# 2          Left Wing        Forward            CAN          CAN
# 3          Left Wing        Forward            CAN          CAN
# 4          Left Wing        Forward            CAN          CAN
# ...              ...            ...            ...          ...
# 37790         Center        Forward            DEU          DEU
# 37791     Defenseman     Defenseman            RUS          RUS
# 37792     Defenseman     Defenseman            RUS          RUS
# 37793     Defenseman     Defenseman            RUS          RUS
# 37794     Defenseman     Defenseman            RUS          RUS
#
# [37795 rows x 46 columns]

# %%
df_main_total
# Out:
#        player_id             name position_code    season  sequenceNumber  \
# 0        8445000  Dave Andreychuk             L  19821983               1
# 1        8445000  Dave Andreychuk             L  19831984               1
# 2        8445000  Dave Andreychuk             L  19841985               1
# 3        8445000  Dave Andreychuk             L  19851986               1
# 4        8445000  Dave Andreychuk             L  19861987               1
# ...          ...              ...           ...       ...             ...
# 37790    8482116      Tim Stützle             C  20232024               1
# 37791    8482245        Artem Zub             D  20202021               1
# 37792    8482245        Artem Zub             D  20212022               1
# 37793    8482245        Artem Zub             D  20222023               1
# 37794    8482245        Artem Zub             D  20232024               1
#
#        stat_assists  stat_goals  stat_games  stat_points        team_name  \
# 0              23.0        14.0          43         37.0   Buffalo Sabres
# 1              42.0        38.0          78         80.0   Buffalo Sabres
# 2              30.0        31.0          64         61.0   Buffalo Sabres
# 3              51.0        36.0          80         87.0   Buffalo Sabres
# 4              48.0        25.0          77         73.0   Buffalo Sabres
# ...             ...         ...         ...          ...              ...
# 37790           4.0         2.0           5          6.0  Ottawa Senators
# 37791          11.0         3.0          47         14.0  Ottawa Senators
# 37792          16.0         6.0          81         22.0  Ottawa Senators
# 37793           7.0         3.0          53         10.0  Ottawa Senators
# 37794           2.0         1.0           4          3.0  Ottawa Senators
#
#        ... season_end weight height  shot_dir           birth_date  age  \
# 0      ...       1983    225  6' 4"         R           1963-09-29   19
# 1      ...       1984    225  6' 4"         R           1963-09-29   20
# 2      ...       1985    225  6' 4"         R           1963-09-29   21
# 3      ...       1986    225  6' 4"         R           1963-09-29   22
# 4      ...       1987    225  6' 4"         R           1963-09-29   23
# ...    ...        ...    ...    ...       ...                  ...  ...
# 37790  ...       2024    197  6' 0"         L  2002-01-15 00:00:00   21
# 37791  ...       2021    204  6' 3"         R  1995-10-03 00:00:00   25
# 37792  ...       2022    204  6' 3"         R  1995-10-03 00:00:00   26
# 37793  ...       2023    204  6' 3"         R  1995-10-03 00:00:00   27
# 37794  ...       2024    204  6' 3"         R  1995-10-03 00:00:00   28
#
#        position_name  position_type  birth_country  nationality
# 0          Left Wing        Forward            CAN          CAN
# 1          Left Wing        Forward            CAN          CAN
# 2          Left Wing        Forward            CAN          CAN
# 3          Left Wing        Forward            CAN          CAN
# 4          Left Wing        Forward            CAN          CAN
# ...              ...            ...            ...          ...
# 37790         Center        Forward            DEU          DEU
# 37791     Defenseman     Defenseman            RUS          RUS
# 37792     Defenseman     Defenseman            RUS          RUS
# 37793     Defenseman     Defenseman            RUS          RUS
# 37794     Defenseman     Defenseman            RUS          RUS
#
# [37795 rows x 46 columns]

# %%
# save to df_main
df_main_total.to_csv('df_main.csv', index=False)

# %% [markdown]
# ### Dropping Rows
#
# The following two blocks of code are used to drop rows of data once a bug has been encountered in the collection process.  The first need for this was after a conditional was incorrectly instantiated that was passing on valuable data.  The first block of code is used to get a list of indices to drop; the second block of code executes the drop over a defined range of indices.  In all cases, we will know the player ID where we want to return to, as it will be defined by the range of the the API call that preceded it.  The code below has been commented out so that it is not accidentally deployed out of turn.

# %%
# Use player_id to find the range of indices to drop
#print(df_main.loc[df_main['player_id'] >= 8448846, :])
# Out:
#        player_id            name position_code    season  sequenceNumber  \
# 11747    8448846     Nick Libett             L  19671968               1
# 11748    8448846     Nick Libett             L  19681969               1
# 11749    8448846     Nick Libett             L  19691970               1
# 11750    8448846     Nick Libett             L  19701971               1
# 11751    8448846     Nick Libett             L  19711972               1
# ...          ...             ...           ...       ...             ...
# 11897    8448873  Mark Lofthouse             R  19801981               1
# 11898    8448873  Mark Lofthouse             R  19811982               1
# 11899    8448873  Mark Lofthouse             R  19821983               1
# 11901    8448876      Barry Long             D  19731974               1
# 11902    8448876      Barry Long             D  19791980               1
#
#        stat_assists  stat_goals  stat_games  stat_points            team_name  \
# 11747           1.0         2.0          22          3.0    Detroit Red Wings
# 11748          14.0        10.0          75         24.0    Detroit Red Wings
# 11749          20.0        20.0          76         40.0    Detroit Red Wings
# 11750          13.0        16.0          78         29.0    Detroit Red Wings
# 11751          22.0        31.0          77         53.0    Detroit Red Wings
# ...             ...         ...         ...          ...                  ...
# 11897           1.0         1.0           3          2.0  Washington Capitals
# 11898           4.0         3.0          12          7.0    Detroit Red Wings
# 11899           4.0         8.0          28         12.0    Detroit Red Wings
# 11901          19.0         3.0          60         22.0    Los Angeles Kings
# 11902          17.0         0.0          80         17.0    Detroit Red Wings
#
#        ... season_end weight height  shot_dir birth_date  age  position_name  \
# 11747  ...       1968    195  6' 1"   unknown 1945-12-09   21      Left Wing
# 11748  ...       1969    195  6' 1"   unknown 1945-12-09   22      Left Wing
# 11749  ...       1970    195  6' 1"   unknown 1945-12-09   23      Left Wing
# 11750  ...       1971    195  6' 1"   unknown 1945-12-09   24      Left Wing
# 11751  ...       1972    195  6' 1"   unknown 1945-12-09   25      Left Wing
# ...    ...        ...    ...    ...       ...        ...  ...            ...
# 11897  ...       1981    195  6' 2"         R 1957-04-21   23     Right Wing
# 11898  ...       1982    195  6' 2"         R 1957-04-21   24     Right Wing
# 11899  ...       1983    195  6' 2"         R 1957-04-21   25     Right Wing
# 11901  ...       1974    210  6' 0"         L 1949-01-31   24     Defenseman
# 11902  ...       1980    210  6' 0"         L 1949-01-31   30     Defenseman
#
#        position_type  birth_country  nationality
# 11747        Forward            CAN          CAN
# 11748        Forward            CAN          CAN
# 11749        Forward            CAN          CAN
# 11750        Forward            CAN          CAN
# 11751        Forward            CAN          CAN
# ...              ...            ...          ...
# 11897        Forward            CAN          CAN
# 11898        Forward            CAN          CAN
# 11899        Forward            CAN          CAN
# 11901     Defenseman            CAN          CAN
# 11902     Defenseman            CAN          CAN
#
# [155 rows x 46 columns]

# %%
# Define the range of indices to drop 
indices_to_drop = list(range(18902, 18903))

# Drop the specified range of indices
df_main = df_main.drop(indices_to_drop)
