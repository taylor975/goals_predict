# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Predicting NHL Goal Scoring - API Debugging </h1></div>

# %% [markdown]
# ***BrainStation Data Science Capstone Project*** <br/>
# ***Author:***  &ensp;    **Taylor Gallivan** <br/>
# ***Date:*** &ensp; **Sep-Nov 2023**

# %% [markdown]
# ### Introduction

# %% [markdown]
# This workbook has been prepared to document the process of writing the scripts used to retrieve my desired data from the NHL's public API.
#
# Each player on the NHL site is assigned a 7-digit ID number, which is needed to access their statistics using with API requests.  I was able to retrieve an up-to-date list of player ID numbers from https://hockey-statistics.com/.  From there, I was able to create a list of all active and inactive players that played in the NHL in the last ~3 decades.
#
# When making my API calls, information was pulled from two endpoints:  `people` and `stats`.  The `people` endpoint contains player bio information, such as first name, last name, weight, height, date of birth, position played, and so on.  The `stats` endpoint, and more particularly the `stats=yearByYear` endpoint, contains season-by-season statistics for each season that a player played in the NHL.  Statistics include features such as number of games played, team played for, number of goals/assists/points scored, average ice time, shots, and so on.
#
# The working piece of code that I deployed first calls the `people` endpoint to retrieve player bio information, then calls the `stats` endpoint to retrieve player statistics, which are immediately converted into a pandas DataFrame.  Next, specific attributes of interest from the `people` endpoint are added to the statistics DataFrame.  A for loop was used to iterate over the entire process, so that I could collect data for all of the player IDs of interest.  Now that the architecture for the data collection is in place, I could go farther back into the 80s if I wanted to increase the size of my training dataset.  That is a decision I will make once the dataset has been partially-cleaned.
#
# What I have tried to document below is the process of familiarizing myself with the API call process, and piecewise testing of my code, building up to the final code block that is being actively deployed for data collection.  Where bugs have been encountered, I have documented the process of resolving them.
#
# I would like to give credit to Nick Paul's personal blog (https://www.nickpaul.info/), as his clear documentation of his personal experience accessing the NHL API was an immense help to my efforts.

# %% [markdown]
# #### Data Dictionary
#
# Below is a partial data dictionary for my project, currently including only the player bio information.  The statistics returned by my pull requests include some features that I plan to omit, and some that I am currently undecided on.  The statistical features will be added to the data dictionary once the list is refined.
#
# - `player_id`:  a player's 7 digit ID number, as assigned by the NHL (int)
# - `first_name`:  player's first name (str)
# - `last_name`:  player's last name (str)
# - `position_code`:  single digit code of a player's position: L, C, R, or D (str)
# - `position_name`:  full name of a player's position:  Left Wing, Center, Right Wing, Defenseman (str)
# - `position_type`:  the category of a player's position:  either Forward or Defenseman (str)
# - `weight`:  player's weight in lbs (int)
# - `height`:  player's height feet & inches (str)
# - `shot_dir`:  which direction a player shoots: left (L) or right (R) (str)
# - `birth_date`:  player's date of birth (str)
# - `birth_country`:  country a player was born in (str)
# - `nationality`:  country a player represents in international competition (str)

# %%
# import key packages
import requests
import json
import pandas as pd
from datetime import datetime
import numpy as np

# %% [markdown]
# ### Exploring NHL API Calls
#
# The code below documents my process in becoming familiar with the accessing the NHL API, retrieving the requisite data, and transforming it into DataFrame format.

# %%
# requesting data from 'people' endpoint
# transform output into a series and display it
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
bio = suggestions[0]
series = (pd.json_normalize(bio))
series
# Out:
#         id   fullName                    link firstName lastName  \
# 0  8445550  Rob Blake  /api/v1/people/8445550       Rob    Blake
#
#   primaryNumber   birthDate birthCity birthStateProvince birthCountry  ...  \
# 0             4  1969-12-10    Simcoe                 ON          CAN  ...
#
#   height weight  active  rookie  shootsCatches rosterStatus  \
# 0  6' 4"    220   False   False              R            Y
#
#   primaryPosition.code primaryPosition.name primaryPosition.type  \
# 0                    D           Defenseman           Defenseman
#
#   primaryPosition.abbreviation
# 0                            D
#
# [1 rows x 21 columns]

# %%
# same as above but for another player
url = 'https://statsapi.web.nhl.com/api/v1/people/8471214'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
bio = suggestions[0]
series = (pd.json_normalize(bio))
series
# Out:
#         id       fullName                    link firstName  lastName  \
# 0  8471214  Alex Ovechkin  /api/v1/people/8471214      Alex  Ovechkin
#
#   primaryNumber   birthDate  currentAge birthCity birthCountry  ... rookie  \
# 0             8  1985-09-17          38    Moscow          RUS  ...  False
#
#   shootsCatches  rosterStatus  currentTeam.id     currentTeam.name  \
# 0             R             Y              15  Washington Capitals
#
#    currentTeam.link  primaryPosition.code primaryPosition.name  \
# 0  /api/v1/teams/15                     L            Left Wing
#
#   primaryPosition.type  primaryPosition.abbreviation
# 0              Forward                            LW
#
# [1 rows x 26 columns]

# %%
# examining the data types of the features in the 'people' endpoint
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
bio = suggestions[0]
series = (pd.json_normalize(bio))
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1 non-null      int64
#  1   fullName                      1 non-null      object
#  2   link                          1 non-null      object
#  3   firstName                     1 non-null      object
#  4   lastName                      1 non-null      object
#  5   primaryNumber                 1 non-null      object
#  6   birthDate                     1 non-null      object
#  7   birthCity                     1 non-null      object
#  8   birthStateProvince            1 non-null      object
#  9   birthCountry                  1 non-null      object
#  10  nationality                   1 non-null      object
#  11  height                        1 non-null      object
#  12  weight                        1 non-null      int64
#  13  active                        1 non-null      bool
#  14  rookie                        1 non-null      bool
#  15  shootsCatches                 1 non-null      object
#  16  rosterStatus                  1 non-null      object
#  17  primaryPosition.code          1 non-null      object
#  18  primaryPosition.name          1 non-null      object
#  19  primaryPosition.type          1 non-null      object
#  20  primaryPosition.abbreviation  1 non-null      object
# dtypes: bool(2), int64(2), object(17)
# memory usage: 286.0+ bytes

# %%
# working out how to pass a value from the 'people' data series
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
#bio = suggestions[0]
series = (pd.json_normalize(suggestions))
#player_id = series['id']
#print(player_id[0])
#first_name = player['firstName']
#first_name

#player_series = series.loc[:, ['id', 'firstName', 'lastName', 'birthDate', 'height', 'weight', 'primaryPosition.code']]
print(series['firstName'][0])
# Out:
# Rob

# %%
# testing output of year by year stats
response = requests.get('https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear')
suggestions = json.loads(response.content)
suggestions
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2023. All Rights Reserved.',
#  'stats': [{'type': {'displayName': 'yearByYear', 'gameType': None},
#    'splits': [{'season': '19851986',
#      'stat': {'timeOnIce': '00:00',
#       'assists': 13,
#       'goals': 3,
#       'pim': 43,
#       'games': 39,
#       'penaltyMinutes': '43',
#       'points': 16},
#      'team': {'name': 'Brantford', 'link': '/api/v1/teams/null'},
#      'league': {'name': 'OHA-B', 'link': '/api/v1/league/null'},
#      'sequenceNumber': 1},
#     {'season': '19861987',
#      'stat': {'assists': 20,
#       'goals': 11,
#       'pim': 115,
#       'games': 31,
#       'penaltyMinutes': '115',
#       'points': 31},
#      'team': {'name': 'Stratford', 'link': '/api/v1/teams/null'},
#      'league': {'name': 'OHA-B', 'link': '/api/v1/league/null'},
#      'sequenceNumber': 1},
#     {'season': '19871988',
#      'stat': {'assists': 8,
#       'goals': 5,
#       'pim': 88,
#       'games': 43,
#       'penaltyMinutes': '88',
#       'points': 13},
#      'team': {'id': 1326,
#       'name': 'Bowling Green',
#       'link': '/api/v1/teams/1326'},
#      'league': {'id': 131, 'name': 'CCHA', 'link': '/api/v1/league/131'},
#      'sequenceNumber': 1},
#     {'season': '19881989',
#      'stat': {'assists': 21,
#       'goals': 11,
#       'pim': 140,
#       'games': 46,
#       'penaltyMinutes': '140',
#       'points': 32},
#      'team': {'id': 1326,
#       'name': 'Bowling Green',
#       'link': '/api/v1/teams/1326'},
#      'league': {'id': 131, 'name': 'CCHA', 'link': '/api/v1/league/131'},
#      'sequenceNumber': 1},
#     {'season': '19891990',
#      'stat': {'assists': 0,
#       'goals': 0,
#       'pim': 4,
#       'shots': 3,
#       'games': 4,
#       'powerPlayGoals': 0,
#       'powerPlayPoints': 0,
#       'penaltyMinutes': '4',
#       'shotPct': 0.0,
#       'gameWinningGoals': 0,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'plusMinus': 0,
#       'points': 0},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19891990',
#      'stat': {'assists': 36,
#       'goals': 23,
#       'pim': 140,
#       'games': 42,
#       'penaltyMinutes': '140',
#       'points': 59},
#      'team': {'id': 1326,
#       'name': 'Bowling Green',
#       'link': '/api/v1/teams/1326'},
#      'league': {'id': 131, 'name': 'CCHA', 'link': '/api/v1/league/131'},
#      'sequenceNumber': 2},
#     {'season': '19901991',
#      'stat': {'assists': 34,
#       'goals': 12,
#       'pim': 125,
#       'shots': 150,
#       'games': 75,
#       'powerPlayGoals': 9,
#       'powerPlayPoints': 25,
#       'penaltyMinutes': '125',
#       'shotPct': 8.0,
#       'gameWinningGoals': 2,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'plusMinus': 3,
#       'points': 46},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19901991',
#      'stat': {'assists': 2,
#       'goals': 0,
#       'pim': 0,
#       'games': 2,
#       'penaltyMinutes': '0',
#       'points': 2},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'WEC-A', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 2},
#     {'season': '19911992',
#      'stat': {'assists': 13,
#       'goals': 7,
#       'pim': 102,
#       'shots': 131,
#       'games': 57,
#       'powerPlayGoals': 5,
#       'powerPlayPoints': 11,
#       'penaltyMinutes': '102',
#       'shotPct': 5.34,
#       'gameWinningGoals': 0,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'plusMinus': -5,
#       'points': 20},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19921993',
#      'stat': {'assists': 43,
#       'goals': 16,
#       'pim': 152,
#       'shots': 243,
#       'games': 76,
#       'powerPlayGoals': 10,
#       'powerPlayPoints': 32,
#       'penaltyMinutes': '152',
#       'shotPct': 6.58,
#       'gameWinningGoals': 4,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 2,
#       'plusMinus': 18,
#       'points': 59},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19931994',
#      'stat': {'assists': 48,
#       'goals': 20,
#       'pim': 137,
#       'shots': 304,
#       'games': 84,
#       'powerPlayGoals': 7,
#       'powerPlayPoints': 33,
#       'penaltyMinutes': '137',
#       'shotPct': 6.58,
#       'gameWinningGoals': 6,
#       'overTimeGoals': 1,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 3,
#       'plusMinus': -7,
#       'points': 68},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19931994',
#      'stat': {'assists': 2,
#       'goals': 0,
#       'pim': 6,
#       'games': 8,
#       'penaltyMinutes': '6',
#       'points': 2},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'WC-A', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 2},
#     {'season': '19941995',
#      'stat': {'assists': 7,
#       'goals': 4,
#       'pim': 38,
#       'shots': 76,
#       'games': 24,
#       'powerPlayGoals': 4,
#       'powerPlayPoints': 6,
#       'penaltyMinutes': '38',
#       'shotPct': 5.26,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'plusMinus': -16,
#       'points': 11},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19951996',
#      'stat': {'assists': 2,
#       'goals': 1,
#       'pim': 8,
#       'shots': 13,
#       'games': 6,
#       'powerPlayGoals': 0,
#       'powerPlayPoints': 2,
#       'penaltyMinutes': '8',
#       'shotPct': 7.69,
#       'gameWinningGoals': 0,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'plusMinus': 0,
#       'points': 3},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19951996',
#      'stat': {'assists': 1,
#       'goals': 0,
#       'pim': 0,
#       'games': 4,
#       'penaltyMinutes': '0',
#       'points': 1},
#      'team': {'name': 'Canada', 'link': '/api/v1/teams/null'},
#      'league': {'name': 'WCup', 'link': '/api/v1/league/null'},
#      'sequenceNumber': 16265},
#     {'season': '19961997',
#      'stat': {'assists': 23,
#       'goals': 8,
#       'pim': 82,
#       'shots': 169,
#       'games': 62,
#       'powerPlayGoals': 4,
#       'powerPlayPoints': 13,
#       'penaltyMinutes': '82',
#       'shotPct': 4.73,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'plusMinus': -28,
#       'points': 31},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19961997',
#      'stat': {'assists': 1,
#       'goals': 0,
#       'pim': 0,
#       'games': 4,
#       'penaltyMinutes': '0',
#       'points': 1},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'W-Cup', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 2},
#     {'season': '19961997',
#      'stat': {'assists': 2,
#       'goals': 2,
#       'pim': 22,
#       'games': 11,
#       'penaltyMinutes': '22',
#       'points': 4},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'WC-A', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 3},
#     {'season': '19971998',
#      'stat': {'timeOnIce': '2141:39',
#       'assists': 27,
#       'goals': 23,
#       'pim': 94,
#       'shots': 261,
#       'games': 81,
#       'hits': 183,
#       'powerPlayGoals': 11,
#       'powerPlayPoints': 22,
#       'powerPlayTimeOnIce': '389:53',
#       'evenTimeOnIce': '1426:44',
#       'penaltyMinutes': '94',
#       'faceOffPct': 0.0,
#       'shotPct': 8.81,
#       'gameWinningGoals': 4,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '325:02',
#       'blocked': 0,
#       'plusMinus': -3,
#       'points': 50,
#       'shifts': 2353},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19971998',
#      'stat': {'assists': 1,
#       'goals': 1,
#       'pim': 2,
#       'games': 6,
#       'penaltyMinutes': '2',
#       'points': 2},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'Olympics', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 2},
#     {'season': '19971998',
#      'stat': {'assists': 0,
#       'goals': 1,
#       'pim': 6,
#       'games': 5,
#       'penaltyMinutes': '6',
#       'points': 1},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'WC-A', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 3},
#     {'season': '19981999',
#      'stat': {'timeOnIce': '1541:13',
#       'assists': 23,
#       'goals': 12,
#       'pim': 128,
#       'shots': 216,
#       'games': 62,
#       'hits': 132,
#       'powerPlayGoals': 5,
#       'powerPlayPoints': 11,
#       'powerPlayTimeOnIce': '252:19',
#       'evenTimeOnIce': '1078:25',
#       'penaltyMinutes': '128',
#       'faceOffPct': 0.0,
#       'shotPct': 5.56,
#       'gameWinningGoals': 2,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 1,
#       'shortHandedPoints': 2,
#       'shortHandedTimeOnIce': '210:29',
#       'blocked': 0,
#       'plusMinus': -7,
#       'points': 35,
#       'shifts': 1667},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '19981999',
#      'stat': {'timeOnIce': '00:00',
#       'assists': 5,
#       'goals': 2,
#       'pim': 12,
#       'games': 10,
#       'penaltyMinutes': '12',
#       'faceOffPct': 0.0,
#       'points': 7},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'WC-A', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 2},
#     {'season': '19992000',
#      'stat': {'timeOnIce': '2193:52',
#       'assists': 39,
#       'goals': 18,
#       'pim': 112,
#       'shots': 327,
#       'games': 77,
#       'hits': 202,
#       'powerPlayGoals': 12,
#       'powerPlayPoints': 26,
#       'powerPlayTimeOnIce': '426:19',
#       'evenTimeOnIce': '1463:09',
#       'penaltyMinutes': '112',
#       'faceOffPct': 0.0,
#       'shotPct': 5.5,
#       'gameWinningGoals': 5,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '304:24',
#       'blocked': 0,
#       'plusMinus': 10,
#       'points': 57,
#       'shifts': 2156},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20002001',
#      'stat': {'timeOnIce': '1521:30',
#       'assists': 32,
#       'goals': 17,
#       'pim': 69,
#       'shots': 223,
#       'games': 54,
#       'hits': 144,
#       'powerPlayGoals': 9,
#       'powerPlayPoints': 26,
#       'powerPlayTimeOnIce': '296:36',
#       'evenTimeOnIce': '1015:54',
#       'penaltyMinutes': '69',
#       'faceOffPct': 0.0,
#       'shotPct': 7.62,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '209:00',
#       'blocked': 0,
#       'plusMinus': -8,
#       'points': 49,
#       'shifts': 1572},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20002001',
#      'stat': {'timeOnIce': '338:37',
#       'assists': 8,
#       'goals': 2,
#       'pim': 8,
#       'shots': 44,
#       'games': 13,
#       'hits': 31,
#       'powerPlayGoals': 1,
#       'powerPlayPoints': 3,
#       'powerPlayTimeOnIce': '72:16',
#       'evenTimeOnIce': '213:56',
#       'penaltyMinutes': '8',
#       'faceOffPct': 0.0,
#       'shotPct': 4.55,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'shortHandedTimeOnIce': '52:25',
#       'blocked': 0,
#       'plusMinus': 11,
#       'points': 10,
#       'shifts': 445},
#      'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 2},
#     {'season': '20012002',
#      'stat': {'timeOnIce': '2068:23',
#       'assists': 40,
#       'goals': 16,
#       'pim': 58,
#       'shots': 229,
#       'games': 75,
#       'hits': 193,
#       'powerPlayGoals': 10,
#       'powerPlayPoints': 27,
#       'powerPlayTimeOnIce': '379:12',
#       'evenTimeOnIce': '1404:48',
#       'penaltyMinutes': '58',
#       'faceOffPct': 0.0,
#       'shotPct': 6.99,
#       'gameWinningGoals': 2,
#       'overTimeGoals': 1,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '284:23',
#       'blocked': 0,
#       'plusMinus': 16,
#       'points': 56,
#       'shifts': 2472},
#      'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20012002',
#      'stat': {'timeOnIce': '00:00',
#       'assists': 2,
#       'goals': 1,
#       'pim': 2,
#       'games': 6,
#       'penaltyMinutes': '2',
#       'faceOffPct': 0.0,
#       'points': 3},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'Olympics', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 2},
#     {'season': '20022003',
#      'stat': {'timeOnIce': '2081:51',
#       'assists': 28,
#       'goals': 17,
#       'pim': 57,
#       'shots': 269,
#       'games': 79,
#       'hits': 93,
#       'powerPlayGoals': 8,
#       'powerPlayPoints': 21,
#       'powerPlayTimeOnIce': '382:54',
#       'evenTimeOnIce': '1381:49',
#       'penaltyMinutes': '57',
#       'faceOffPct': 0.0,
#       'shotPct': 6.32,
#       'gameWinningGoals': 3,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 2,
#       'shortHandedPoints': 3,
#       'shortHandedTimeOnIce': '317:08',
#       'blocked': 33,
#       'plusMinus': 20,
#       'points': 45,
#       'shifts': 2749},
#      'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20032004',
#      'stat': {'timeOnIce': '1804:57',
#       'assists': 33,
#       'goals': 13,
#       'pim': 61,
#       'shots': 242,
#       'games': 74,
#       'hits': 136,
#       'powerPlayGoals': 8,
#       'powerPlayPoints': 26,
#       'powerPlayTimeOnIce': '321:01',
#       'evenTimeOnIce': '1258:17',
#       'penaltyMinutes': '61',
#       'faceOffPct': 0.0,
#       'shotPct': 5.37,
#       'gameWinningGoals': 3,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '225:39',
#       'blocked': 0,
#       'plusMinus': 6,
#       'points': 46,
#       'shifts': 2531},
#      'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20052006',
#      'stat': {'timeOnIce': '1974:11',
#       'assists': 37,
#       'goals': 14,
#       'pim': 94,
#       'shots': 264,
#       'games': 81,
#       'hits': 108,
#       'powerPlayGoals': 7,
#       'powerPlayPoints': 24,
#       'powerPlayTimeOnIce': '432:27',
#       'evenTimeOnIce': '1192:27',
#       'penaltyMinutes': '94',
#       'faceOffPct': 0.0,
#       'shotPct': 5.3,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 1,
#       'shortHandedPoints': 2,
#       'shortHandedTimeOnIce': '349:17',
#       'blocked': 175,
#       'plusMinus': 2,
#       'points': 51,
#       'shifts': 2708},
#      'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20052006',
#      'stat': {'timeOnIce': '00:00',
#       'assists': 1,
#       'goals': 0,
#       'pim': 2,
#       'games': 6,
#       'powerPlayTimeOnIce': '00:00',
#       'evenTimeOnIce': '00:00',
#       'penaltyMinutes': '2',
#       'faceOffPct': 0.0,
#       'shortHandedTimeOnIce': '00:00',
#       'points': 1,
#       'shifts': 0},
#      'team': {'id': 60, 'name': 'Canada', 'link': '/api/v1/teams/60'},
#      'league': {'id': 147, 'name': 'Olympics', 'link': '/api/v1/league/147'},
#      'sequenceNumber': 3},
#     {'season': '20062007',
#      'stat': {'timeOnIce': '1756:30',
#       'assists': 20,
#       'goals': 14,
#       'pim': 82,
#       'shots': 208,
#       'games': 72,
#       'hits': 95,
#       'powerPlayGoals': 11,
#       'powerPlayPoints': 26,
#       'powerPlayTimeOnIce': '369:20',
#       'evenTimeOnIce': '1114:15',
#       'penaltyMinutes': '82',
#       'faceOffPct': 33.33,
#       'shotPct': 6.73,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '272:55',
#       'blocked': 127,
#       'plusMinus': -26,
#       'points': 34,
#       'shifts': 2232},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20072008',
#      'stat': {'timeOnIce': '1614:04',
#       'assists': 22,
#       'goals': 9,
#       'pim': 98,
#       'shots': 144,
#       'games': 71,
#       'hits': 93,
#       'powerPlayGoals': 5,
#       'powerPlayPoints': 15,
#       'powerPlayTimeOnIce': '278:47',
#       'evenTimeOnIce': '1088:45',
#       'penaltyMinutes': '98',
#       'faceOffPct': 50.0,
#       'shotPct': 6.25,
#       'gameWinningGoals': 2,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'shortHandedTimeOnIce': '246:32',
#       'blocked': 143,
#       'plusMinus': -19,
#       'points': 31,
#       'shifts': 1933},
#      'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20082009',
#      'stat': {'timeOnIce': '1552:56',
#       'assists': 35,
#       'goals': 10,
#       'pim': 110,
#       'shots': 198,
#       'games': 73,
#       'hits': 66,
#       'powerPlayGoals': 6,
#       'powerPlayPoints': 22,
#       'powerPlayTimeOnIce': '221:18',
#       'evenTimeOnIce': '1148:42',
#       'penaltyMinutes': '110',
#       'faceOffPct': 0.0,
#       'shotPct': 5.05,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 0,
#       'shortHandedTimeOnIce': '182:56',
#       'blocked': 114,
#       'plusMinus': 15,
#       'points': 45,
#       'shifts': 1960},
#      'team': {'id': 28, 'name': 'San Jose Sharks', 'link': '/api/v1/teams/28'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1},
#     {'season': '20092010',
#      'stat': {'timeOnIce': '1494:36',
#       'assists': 23,
#       'goals': 7,
#       'pim': 60,
#       'shots': 182,
#       'games': 70,
#       'hits': 68,
#       'powerPlayGoals': 4,
#       'powerPlayPoints': 8,
#       'powerPlayTimeOnIce': '163:24',
#       'evenTimeOnIce': '1129:20',
#       'penaltyMinutes': '60',
#       'faceOffPct': 0.0,
#       'shotPct': 3.85,
#       'gameWinningGoals': 1,
#       'overTimeGoals': 0,
#       'shortHandedGoals': 0,
#       'shortHandedPoints': 1,
#       'shortHandedTimeOnIce': '201:52',
#       'blocked': 114,
#       'plusMinus': 14,
#       'points': 30,
#       'shifts': 1990},
#      'team': {'id': 28, 'name': 'San Jose Sharks', 'link': '/api/v1/teams/28'},
#      'league': {'id': 133,
#       'name': 'National Hockey League',
#       'link': '/api/v1/league/133'},
#      'sequenceNumber': 1}]}]}

# %%
# transforming json output into a pandas dataframe
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear'
response = requests.get(url)
content = json.loads(response.content)['stats']
splits = content[0]['splits']

# the NHL API stores player stats from development leagues, we only care about NHL stats
df_splits = (pd.json_normalize(splits, sep = "_" )
             .query('league_name == "National Hockey League"')  
            )
df_splits
# Out:
#       season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 4   19891990               1            NaN             0           0
# 6   19901991               1            NaN            34          12
# 8   19911992               1            NaN            13           7
# 9   19921993               1            NaN            43          16
# 10  19931994               1            NaN            48          20
# 12  19941995               1            NaN             7           4
# 13  19951996               1            NaN             2           1
# 15  19961997               1            NaN            23           8
# 18  19971998               1        2141:39            27          23
# 21  19981999               1        1541:13            23          12
# 23  19992000               1        2193:52            39          18
# 24  20002001               1        1521:30            32          17
# 25  20002001               2         338:37             8           2
# 26  20012002               1        2068:23            40          16
# 28  20022003               1        2081:51            28          17
# 29  20032004               1        1804:57            33          13
# 30  20052006               1        1974:11            37          14
# 32  20062007               1        1756:30            20          14
# 33  20072008               1        1614:04            22           9
# 34  20082009               1        1552:56            35          10
# 35  20092010               1        1494:36            23           7
#
#     stat_pim  stat_games stat_penaltyMinutes  stat_points           team_name  \
# 4          4           4                   4            0   Los Angeles Kings
# 6        125          75                 125           46   Los Angeles Kings
# 8        102          57                 102           20   Los Angeles Kings
# 9        152          76                 152           59   Los Angeles Kings
# 10       137          84                 137           68   Los Angeles Kings
# 12        38          24                  38           11   Los Angeles Kings
# 13         8           6                   8            3   Los Angeles Kings
# 15        82          62                  82           31   Los Angeles Kings
# 18        94          81                  94           50   Los Angeles Kings
# 21       128          62                 128           35   Los Angeles Kings
# 23       112          77                 112           57   Los Angeles Kings
# 24        69          54                  69           49   Los Angeles Kings
# 25         8          13                   8           10  Colorado Avalanche
# 26        58          75                  58           56  Colorado Avalanche
# 28        57          79                  57           45  Colorado Avalanche
# 29        61          74                  61           46  Colorado Avalanche
# 30        94          81                  94           51  Colorado Avalanche
# 32        82          72                  82           34   Los Angeles Kings
# 33        98          71                  98           31   Los Angeles Kings
# 34       110          73                 110           45     San Jose Sharks
# 35        60          70                  60           30     San Jose Sharks
#
#     ... stat_shortHandedGoals stat_shortHandedPoints stat_plusMinus  \
# 4   ...                   0.0                    0.0            0.0
# 6   ...                   0.0                    0.0            3.0
# 8   ...                   0.0                    0.0           -5.0
# 9   ...                   0.0                    2.0           18.0
# 10  ...                   0.0                    3.0           -7.0
# 12  ...                   0.0                    0.0          -16.0
# 13  ...                   0.0                    0.0            0.0
# 15  ...                   0.0                    0.0          -28.0
# 18  ...                   0.0                    1.0           -3.0
# 21  ...                   1.0                    2.0           -7.0
# 23  ...                   0.0                    1.0           10.0
# 24  ...                   0.0                    1.0           -8.0
# 25  ...                   0.0                    0.0           11.0
# 26  ...                   0.0                    1.0           16.0
# 28  ...                   2.0                    3.0           20.0
# 29  ...                   0.0                    1.0            6.0
# 30  ...                   1.0                    2.0            2.0
# 32  ...                   0.0                    1.0          -26.0
# 33  ...                   0.0                    0.0          -19.0
# 34  ...                   0.0                    0.0           15.0
# 35  ...                   0.0                    1.0           14.0
#
#     stat_hits  stat_powerPlayTimeOnIce  stat_evenTimeOnIce  stat_faceOffPct  \
# 4         NaN                      NaN                 NaN              NaN
# 6         NaN                      NaN                 NaN              NaN
# 8         NaN                      NaN                 NaN              NaN
# 9         NaN                      NaN                 NaN              NaN
# 10        NaN                      NaN                 NaN              NaN
# 12        NaN                      NaN                 NaN              NaN
# 13        NaN                      NaN                 NaN              NaN
# 15        NaN                      NaN                 NaN              NaN
# 18      183.0                   389:53             1426:44             0.00
# 21      132.0                   252:19             1078:25             0.00
# 23      202.0                   426:19             1463:09             0.00
# 24      144.0                   296:36             1015:54             0.00
# 25       31.0                    72:16              213:56             0.00
# 26      193.0                   379:12             1404:48             0.00
# 28       93.0                   382:54             1381:49             0.00
# 29      136.0                   321:01             1258:17             0.00
# 30      108.0                   432:27             1192:27             0.00
# 32       95.0                   369:20             1114:15            33.33
# 33       93.0                   278:47             1088:45            50.00
# 34       66.0                   221:18             1148:42             0.00
# 35       68.0                   163:24             1129:20             0.00
#
#     stat_shortHandedTimeOnIce  stat_blocked  stat_shifts
# 4                         NaN           NaN          NaN
# 6                         NaN           NaN          NaN
# 8                         NaN           NaN          NaN
# 9                         NaN           NaN          NaN
# 10                        NaN           NaN          NaN
# 12                        NaN           NaN          NaN
# 13                        NaN           NaN          NaN
# 15                        NaN           NaN          NaN
# 18                     325:02           0.0       2353.0
# 21                     210:29           0.0       1667.0
# 23                     304:24           0.0       2156.0
# 24                     209:00           0.0       1572.0
# 25                      52:25           0.0        445.0
# 26                     284:23           0.0       2472.0
# 28                     317:08          33.0       2749.0
# 29                     225:39           0.0       2531.0
# 30                     349:17         175.0       2708.0
# 32                     272:55         127.0       2232.0
# 33                     246:32         143.0       1933.0
# 34                     182:56         114.0       1960.0
# 35                     201:52         114.0       1990.0
#
# [21 rows x 31 columns]

# %%
# view the columns outputted by 'stats' endpoint
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear'
response = requests.get(url)
content = json.loads(response.content)['stats']
splits = content[0]['splits']

df_splits = (pd.json_normalize(splits, sep = "_" )
             .query('league_name == "National Hockey League"')
            )

df_splits.columns
# Out:
# Index(['season', 'sequenceNumber', 'stat_timeOnIce', 'stat_assists',
#        'stat_goals', 'stat_pim', 'stat_games', 'stat_penaltyMinutes',
#        'stat_points', 'team_name', 'team_link', 'league_name', 'league_link',
#        'team_id', 'league_id', 'stat_shots', 'stat_powerPlayGoals',
#        'stat_powerPlayPoints', 'stat_shotPct', 'stat_gameWinningGoals',
#        'stat_overTimeGoals', 'stat_shortHandedGoals', 'stat_shortHandedPoints',
#        'stat_plusMinus', 'stat_hits', 'stat_powerPlayTimeOnIce',
#        'stat_evenTimeOnIce', 'stat_faceOffPct', 'stat_shortHandedTimeOnIce',
#        'stat_blocked', 'stat_shifts'],
#       dtype='object')

# %%
# check the data types in 'stats' endpoint
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear'
response = requests.get(url)
content = json.loads(response.content)['stats']
splits = content[0]['splits']

df_splits = (pd.json_normalize(splits, sep = "_" )
             .query('league_name == "National Hockey League"')
            )

df_splits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 4 to 35
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   season                     21 non-null     object
#  1   sequenceNumber             21 non-null     int64
#  2   stat_timeOnIce             13 non-null     object
#  3   stat_assists               21 non-null     int64
#  4   stat_goals                 21 non-null     int64
#  5   stat_pim                   21 non-null     int64
#  6   stat_games                 21 non-null     int64
#  7   stat_penaltyMinutes        21 non-null     object
#  8   stat_points                21 non-null     int64
#  9   team_name                  21 non-null     object
#  10  team_link                  21 non-null     object
#  11  league_name                21 non-null     object
#  12  league_link                21 non-null     object
#  13  team_id                    21 non-null     float64
#  14  league_id                  21 non-null     float64
#  15  stat_shots                 21 non-null     float64
#  16  stat_powerPlayGoals        21 non-null     float64
#  17  stat_powerPlayPoints       21 non-null     float64
#  18  stat_shotPct               21 non-null     float64
#  19  stat_gameWinningGoals      21 non-null     float64
#  20  stat_overTimeGoals         21 non-null     float64
#  21  stat_shortHandedGoals      21 non-null     float64
#  22  stat_shortHandedPoints     21 non-null     float64
#  23  stat_plusMinus             21 non-null     float64
#  24  stat_hits                  13 non-null     float64
#  25  stat_powerPlayTimeOnIce    13 non-null     object
#  26  stat_evenTimeOnIce         13 non-null     object
#  27  stat_faceOffPct            13 non-null     float64
#  28  stat_shortHandedTimeOnIce  13 non-null     object
#  29  stat_blocked               13 non-null     float64
#  30  stat_shifts                13 non-null     float64
# dtypes: float64(15), int64(6), object(10)
# memory usage: 5.2+ KB

# %%
# testing how to pass player bio info into player stats DataFrame
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
player = (pd.json_normalize(suggestions))

url = 'https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear'
response = requests.get(url)
content = json.loads(response.content)['stats']
splits = content[0]['splits']

df_splits = (pd.json_normalize(splits, sep = "_" )
             .query('league_name == "National Hockey League"')
            )

df_splits['player_id'] = player['id'][0]
df_splits['first_name'] = player['firstName'][0]
df_splits['last_name'] = player['lastName'][0]
df_splits['bday'] = pd.to_datetime(player['birthDate'][0])
# Determines the season start year, from column 'season'
df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
# Determines the season start year from column 'seasons'
df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
# Sets the season start date
df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
# Calculates the player's age at the start of a given season
df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['bday'])/ np.timedelta64(1,'Y') ))
# Convert age to int datatype
df_splits['age'] = df_splits['age'].astype(int)

df_splits
# Out:
#       season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 4   19891990               1            NaN             0           0
# 6   19901991               1            NaN            34          12
# 8   19911992               1            NaN            13           7
# 9   19921993               1            NaN            43          16
# 10  19931994               1            NaN            48          20
# 12  19941995               1            NaN             7           4
# 13  19951996               1            NaN             2           1
# 15  19961997               1            NaN            23           8
# 18  19971998               1        2141:39            27          23
# 21  19981999               1        1541:13            23          12
# 23  19992000               1        2193:52            39          18
# 24  20002001               1        1521:30            32          17
# 25  20002001               2         338:37             8           2
# 26  20012002               1        2068:23            40          16
# 28  20022003               1        2081:51            28          17
# 29  20032004               1        1804:57            33          13
# 30  20052006               1        1974:11            37          14
# 32  20062007               1        1756:30            20          14
# 33  20072008               1        1614:04            22           9
# 34  20082009               1        1552:56            35          10
# 35  20092010               1        1494:36            23           7
#
#     stat_pim  stat_games stat_penaltyMinutes  stat_points           team_name  \
# 4          4           4                   4            0   Los Angeles Kings
# 6        125          75                 125           46   Los Angeles Kings
# 8        102          57                 102           20   Los Angeles Kings
# 9        152          76                 152           59   Los Angeles Kings
# 10       137          84                 137           68   Los Angeles Kings
# 12        38          24                  38           11   Los Angeles Kings
# 13         8           6                   8            3   Los Angeles Kings
# 15        82          62                  82           31   Los Angeles Kings
# 18        94          81                  94           50   Los Angeles Kings
# 21       128          62                 128           35   Los Angeles Kings
# 23       112          77                 112           57   Los Angeles Kings
# 24        69          54                  69           49   Los Angeles Kings
# 25         8          13                   8           10  Colorado Avalanche
# 26        58          75                  58           56  Colorado Avalanche
# 28        57          79                  57           45  Colorado Avalanche
# 29        61          74                  61           46  Colorado Avalanche
# 30        94          81                  94           51  Colorado Avalanche
# 32        82          72                  82           34   Los Angeles Kings
# 33        98          71                  98           31   Los Angeles Kings
# 34       110          73                 110           45     San Jose Sharks
# 35        60          70                  60           30     San Jose Sharks
#
#     ... stat_blocked stat_shifts player_id  first_name  last_name       bday  \
# 4   ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 6   ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 8   ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 9   ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 10  ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 12  ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 13  ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 15  ...          NaN         NaN   8445550         Rob      Blake 1969-12-10
# 18  ...          0.0      2353.0   8445550         Rob      Blake 1969-12-10
# 21  ...          0.0      1667.0   8445550         Rob      Blake 1969-12-10
# 23  ...          0.0      2156.0   8445550         Rob      Blake 1969-12-10
# 24  ...          0.0      1572.0   8445550         Rob      Blake 1969-12-10
# 25  ...          0.0       445.0   8445550         Rob      Blake 1969-12-10
# 26  ...          0.0      2472.0   8445550         Rob      Blake 1969-12-10
# 28  ...         33.0      2749.0   8445550         Rob      Blake 1969-12-10
# 29  ...          0.0      2531.0   8445550         Rob      Blake 1969-12-10
# 30  ...        175.0      2708.0   8445550         Rob      Blake 1969-12-10
# 32  ...        127.0      2232.0   8445550         Rob      Blake 1969-12-10
# 33  ...        143.0      1933.0   8445550         Rob      Blake 1969-12-10
# 34  ...        114.0      1960.0   8445550         Rob      Blake 1969-12-10
# 35  ...        114.0      1990.0   8445550         Rob      Blake 1969-12-10
#
#     season_end  season_start_yr  season_start_dt  age
# 4         1990             1989       1989-09-30   19
# 6         1991             1990       1990-09-30   20
# 8         1992             1991       1991-09-30   21
# 9         1993             1992       1992-09-30   22
# 10        1994             1993       1993-09-30   23
# 12        1995             1994       1994-09-30   24
# 13        1996             1995       1995-09-30   25
# 15        1997             1996       1996-09-30   26
# 18        1998             1997       1997-09-30   27
# 21        1999             1998       1998-09-30   28
# 23        2000             1999       1999-09-30   29
# 24        2001             2000       2000-09-30   30
# 25        2001             2000       2000-09-30   30
# 26        2002             2001       2001-09-30   31
# 28        2003             2002       2002-09-30   32
# 29        2004             2003       2003-09-30   33
# 30        2006             2005       2005-09-30   35
# 32        2007             2006       2006-09-30   36
# 33        2008             2007       2007-09-30   37
# 34        2009             2008       2008-09-30   38
# 35        2010             2009       2009-09-30   39
#
# [21 rows x 39 columns]

# %%
# increasing DataFrame complexity
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
player = (pd.json_normalize(suggestions))

url = 'https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear'
response = requests.get(url)
content = json.loads(response.content)['stats']
splits = content[0]['splits']

df_splits = (pd.json_normalize(splits, sep = "_" )
             .query('league_name == "National Hockey League"')
            )

df_splits['player_id'] = player['id'][0]
df_splits['first_name'] = player['firstName'][0]
df_splits['last_name'] = player['lastName'][0]
df_splits['position_code'] = player['primaryPosition.code'][0]

df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
df_splits['season_end'] = [x[4:8] for x in df_splits['season']]

df_splits['weight'] = player['weight'][0]
df_splits['height'] = player['height'][0]
df_splits['shot_dir'] = player['shootsCatches'][0]
df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
df_splits['age'] = df_splits['age'].astype(int)
df_splits['position_name'] = player['primaryPosition.name'][0]
df_splits['position_type'] = player['primaryPosition.type'][0]
df_splits['birth_country'] = player['birthCountry'][0]
df_splits['nationality'] = player['nationality'][0]


df_splits
# Out:
#       season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 4   19891990               1            NaN             0           0
# 6   19901991               1            NaN            34          12
# 8   19911992               1            NaN            13           7
# 9   19921993               1            NaN            43          16
# 10  19931994               1            NaN            48          20
# 12  19941995               1            NaN             7           4
# 13  19951996               1            NaN             2           1
# 15  19961997               1            NaN            23           8
# 18  19971998               1        2141:39            27          23
# 21  19981999               1        1541:13            23          12
# 23  19992000               1        2193:52            39          18
# 24  20002001               1        1521:30            32          17
# 25  20002001               2         338:37             8           2
# 26  20012002               1        2068:23            40          16
# 28  20022003               1        2081:51            28          17
# 29  20032004               1        1804:57            33          13
# 30  20052006               1        1974:11            37          14
# 32  20062007               1        1756:30            20          14
# 33  20072008               1        1614:04            22           9
# 34  20082009               1        1552:56            35          10
# 35  20092010               1        1494:36            23           7
#
#     stat_pim  stat_games stat_penaltyMinutes  stat_points           team_name  \
# 4          4           4                   4            0   Los Angeles Kings
# 6        125          75                 125           46   Los Angeles Kings
# 8        102          57                 102           20   Los Angeles Kings
# 9        152          76                 152           59   Los Angeles Kings
# 10       137          84                 137           68   Los Angeles Kings
# 12        38          24                  38           11   Los Angeles Kings
# 13         8           6                   8            3   Los Angeles Kings
# 15        82          62                  82           31   Los Angeles Kings
# 18        94          81                  94           50   Los Angeles Kings
# 21       128          62                 128           35   Los Angeles Kings
# 23       112          77                 112           57   Los Angeles Kings
# 24        69          54                  69           49   Los Angeles Kings
# 25         8          13                   8           10  Colorado Avalanche
# 26        58          75                  58           56  Colorado Avalanche
# 28        57          79                  57           45  Colorado Avalanche
# 29        61          74                  61           46  Colorado Avalanche
# 30        94          81                  94           51  Colorado Avalanche
# 32        82          72                  82           34   Los Angeles Kings
# 33        98          71                  98           31   Los Angeles Kings
# 34       110          73                 110           45     San Jose Sharks
# 35        60          70                  60           30     San Jose Sharks
#
#     ... season_end weight height  shot_dir  birth_date  age  position_name  \
# 4   ...       1990    220  6' 4"         R  1969-12-10   19     Defenseman
# 6   ...       1991    220  6' 4"         R  1969-12-10   20     Defenseman
# 8   ...       1992    220  6' 4"         R  1969-12-10   21     Defenseman
# 9   ...       1993    220  6' 4"         R  1969-12-10   22     Defenseman
# 10  ...       1994    220  6' 4"         R  1969-12-10   23     Defenseman
# 12  ...       1995    220  6' 4"         R  1969-12-10   24     Defenseman
# 13  ...       1996    220  6' 4"         R  1969-12-10   25     Defenseman
# 15  ...       1997    220  6' 4"         R  1969-12-10   26     Defenseman
# 18  ...       1998    220  6' 4"         R  1969-12-10   27     Defenseman
# 21  ...       1999    220  6' 4"         R  1969-12-10   28     Defenseman
# 23  ...       2000    220  6' 4"         R  1969-12-10   29     Defenseman
# 24  ...       2001    220  6' 4"         R  1969-12-10   30     Defenseman
# 25  ...       2001    220  6' 4"         R  1969-12-10   30     Defenseman
# 26  ...       2002    220  6' 4"         R  1969-12-10   31     Defenseman
# 28  ...       2003    220  6' 4"         R  1969-12-10   32     Defenseman
# 29  ...       2004    220  6' 4"         R  1969-12-10   33     Defenseman
# 30  ...       2006    220  6' 4"         R  1969-12-10   35     Defenseman
# 32  ...       2007    220  6' 4"         R  1969-12-10   36     Defenseman
# 33  ...       2008    220  6' 4"         R  1969-12-10   37     Defenseman
# 34  ...       2009    220  6' 4"         R  1969-12-10   38     Defenseman
# 35  ...       2010    220  6' 4"         R  1969-12-10   39     Defenseman
#
#     position_type  birth_country  nationality
# 4      Defenseman            CAN          CAN
# 6      Defenseman            CAN          CAN
# 8      Defenseman            CAN          CAN
# 9      Defenseman            CAN          CAN
# 10     Defenseman            CAN          CAN
# 12     Defenseman            CAN          CAN
# 13     Defenseman            CAN          CAN
# 15     Defenseman            CAN          CAN
# 18     Defenseman            CAN          CAN
# 21     Defenseman            CAN          CAN
# 23     Defenseman            CAN          CAN
# 24     Defenseman            CAN          CAN
# 25     Defenseman            CAN          CAN
# 26     Defenseman            CAN          CAN
# 28     Defenseman            CAN          CAN
# 29     Defenseman            CAN          CAN
# 30     Defenseman            CAN          CAN
# 32     Defenseman            CAN          CAN
# 33     Defenseman            CAN          CAN
# 34     Defenseman            CAN          CAN
# 35     Defenseman            CAN          CAN
#
# [21 rows x 47 columns]

# %%
# confirming that the shape matches what is expected
url = 'https://statsapi.web.nhl.com/api/v1/people/8445550'
response = requests.get(url)
suggestions = json.loads(response.content)['people']
player = (pd.json_normalize(suggestions))

url = 'https://statsapi.web.nhl.com/api/v1/people/8445550/stats/?stats=yearByYear'
response = requests.get(url)
content = json.loads(response.content)['stats']
splits = content[0]['splits']

df_splits = (pd.json_normalize(splits, sep = "_" )
             .query('league_name == "National Hockey League"')
            )

df_splits['player_id'] = player['id'][0]
df_splits['first_name'] = player['firstName'][0]
df_splits['last_name'] = player['lastName'][0]
df_splits['position_code'] = player['primaryPosition.code'][0]

df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
df_splits['season_end'] = [x[4:8] for x in df_splits['season']]

df_splits['weight'] = player['weight'][0]
df_splits['height'] = player['height'][0]
df_splits['shot_dir'] = player['shootsCatches'][0]
df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
df_splits['age'] = df_splits['age'].astype(int)
df_splits['position_name'] = player['primaryPosition.name'][0]
df_splits['position_type'] = player['primaryPosition.type'][0]
df_splits['birth_country'] = player['birthCountry'][0]
df_splits['nationality'] = player['nationality'][0]


df_splits.shape
# Out:
# (21, 47)

# %% [markdown]
# ### Implementing Conditionals
#
# Now that we are confident in the API call process, we can start setting up our iteration to parse through the list of player IDs.  This can be accomplished using a for loop.  Our initial list of player IDs will be: 8445550 - 8482246.
#
# Within the loop, we will need to make two endpoint calls:  one to `people` and one to `stats`.  The following conditions will be included in the code:
# - if the player's position code is 'G' (goaltender), pass
# - if a player has played less than 3 seasons in the NHL, pass
# - if a player has played less than 200 career games in the NHL, pass
#
# Another pass to consider, which could be part of a successive data cleaning effort, would be to only consider seasons where a player played over, say, 15 games.  This is close to the 20% mark of a season.  If sample sizes are too small, they will be more sensitive to 'noise' (i.e., a hot or cold streak that is misleading)
#
# For any player who passes all pass conditions, the dataframe of their statistics will be added to the larger dataframe containing all players (who meet our criteria).

# %%
# testing URL concatenation, with very simple for loop

# set base URL, which player ID number will be added to
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'

# Set a range for loop
range1 = range(8445549, 8445551)  

for num in range1:
    url = f'{base_url}{num}'  # f-strings used to concatenate the player ID onto the URL for the API call
    print(url)
# Out:
# https://statsapi.web.nhl.com/api/v1/people/8445549
# https://statsapi.web.nhl.com/api/v1/people/8445550

# %% [markdown]
# One thing that was identified early on in this stage is that for some player IDs there is no information stored.  In that case, an error is thrown when we try to pull informataion from the `people` endpoint.  Below is the code I deployed to figure out the response code of the error.  After some web searching, I found the `.status_code` command which can be used to make logical decisions when a the error response code is thrown (i.e., not break the code!)

# %%
# this player ID broke my code - check response code
url = 'https://statsapi.web.nhl.com/api/v1/people/8445552'
response = requests.get(url)
print(response)
# Out:
# <Response [404]>

# %%
# testing .status_code function
url = 'https://statsapi.web.nhl.com/api/v1/people/8445552'
response = requests.get(url)
if response.status_code == 404:
    print('yes')
else:  
    print('no')
# Out:
# yes

# %% [markdown]
# For the next block of code, I pulled together my two debugged API calls for `people` and `stats`, as well as a conditional statement to pass responses returning a [404] response.
#
# After the calling the `people` endpoint, the code checks if the position of the player is a goaltender (and passes if so).  AFter calling the `stats` endpoint, the code checks if the resulting DataFrame has less than 3 rows, which would mean the player played in less than 3 seasons (and passes if so).
#
# For simplicity of code, I did not add all of my desired variables from `people` into the outputted DataFrame.  After completing debugging, all of the desired variables will be included.

# %%
# Pulling pieces together and testing conditional statements
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'

# modest range of 10 player IDs
range1 = range(8445550, 8445560)

for num in range1:
    url = f'{base_url}{num}'
    response = requests.get(url)
    
    # evaluate response code, pass if 404
    if response.status_code == 404:
        pass
    else:
        bio = json.loads(response.content)['people']
        player = (pd.json_normalize(bio))
        
        # evaluate player position, pass if 'G' (goaltender)
        if player['primaryPosition.code'][0] == 'G':
            pass
        else:
            url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(url)
            content = json.loads(response.content)['stats']
            splits = content[0]['splits']
            
            df_splits = (pd.json_normalize(splits, sep = "_" )
                         .query('league_name == "National Hockey League"')
                        )
            
            # evaluate how many seasons a player has played, pass if less than 3
            if df_splits.shape[0] < 3:
                pass
            else:
                df_splits['player_id'] = player['id'][0]
                df_splits['first_name'] = player['firstName'][0]
                df_splits['last_name'] = player['lastName'][0]
                df_splits['position_code'] = player['primaryPosition.code'][0]
                
                # print the DataFrame to check output is correct
                print(df_splits)
# Out:
#       season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 4   19891990               1            NaN             0           0
# 6   19901991               1            NaN            34          12
# 8   19911992               1            NaN            13           7
# 9   19921993               1            NaN            43          16
# 10  19931994               1            NaN            48          20
# 12  19941995               1            NaN             7           4
# 13  19951996               1            NaN             2           1
# 15  19961997               1            NaN            23           8
# 18  19971998               1        2141:39            27          23
# 21  19981999               1        1541:13            23          12
# 23  19992000               1        2193:52            39          18
# 24  20002001               1        1521:30            32          17
# 25  20002001               2         338:37             8           2
# 26  20012002               1        2068:23            40          16
# 28  20022003               1        2081:51            28          17
# 29  20032004               1        1804:57            33          13
# 30  20052006               1        1974:11            37          14
# 32  20062007               1        1756:30            20          14
# 33  20072008               1        1614:04            22           9
# 34  20082009               1        1552:56            35          10
# 35  20092010               1        1494:36            23           7
#
#     stat_pim  stat_games stat_penaltyMinutes  stat_points           team_name  \
# 4          4           4                   4            0   Los Angeles Kings
# 6        125          75                 125           46   Los Angeles Kings
# 8        102          57                 102           20   Los Angeles Kings
# 9        152          76                 152           59   Los Angeles Kings
# 10       137          84                 137           68   Los Angeles Kings
# 12        38          24                  38           11   Los Angeles Kings
# 13         8           6                   8            3   Los Angeles Kings
# 15        82          62                  82           31   Los Angeles Kings
# 18        94          81                  94           50   Los Angeles Kings
# 21       128          62                 128           35   Los Angeles Kings
# 23       112          77                 112           57   Los Angeles Kings
# 24        69          54                  69           49   Los Angeles Kings
# 25         8          13                   8           10  Colorado Avalanche
# 26        58          75                  58           56  Colorado Avalanche
# 28        57          79                  57           45  Colorado Avalanche
# 29        61          74                  61           46  Colorado Avalanche
# 30        94          81                  94           51  Colorado Avalanche
# 32        82          72                  82           34   Los Angeles Kings
# 33        98          71                  98           31   Los Angeles Kings
# 34       110          73                 110           45     San Jose Sharks
# 35        60          70                  60           30     San Jose Sharks
#
#     ... stat_powerPlayTimeOnIce stat_evenTimeOnIce stat_faceOffPct  \
# 4   ...                     NaN                NaN             NaN
# 6   ...                     NaN                NaN             NaN
# 8   ...                     NaN                NaN             NaN
# 9   ...                     NaN                NaN             NaN
# 10  ...                     NaN                NaN             NaN
# 12  ...                     NaN                NaN             NaN
# 13  ...                     NaN                NaN             NaN
# 15  ...                     NaN                NaN             NaN
# 18  ...                  389:53            1426:44            0.00
# 21  ...                  252:19            1078:25            0.00
# 23  ...                  426:19            1463:09            0.00
# 24  ...                  296:36            1015:54            0.00
# 25  ...                   72:16             213:56            0.00
# 26  ...                  379:12            1404:48            0.00
# 28  ...                  382:54            1381:49            0.00
# 29  ...                  321:01            1258:17            0.00
# 30  ...                  432:27            1192:27            0.00
# 32  ...                  369:20            1114:15           33.33
# 33  ...                  278:47            1088:45           50.00
# 34  ...                  221:18            1148:42            0.00
# 35  ...                  163:24            1129:20            0.00
#
#     stat_shortHandedTimeOnIce  stat_blocked  stat_shifts  player_id  \
# 4                         NaN           NaN          NaN    8445550
# 6                         NaN           NaN          NaN    8445550
# 8                         NaN           NaN          NaN    8445550
# 9                         NaN           NaN          NaN    8445550
# 10                        NaN           NaN          NaN    8445550
# 12                        NaN           NaN          NaN    8445550
# 13                        NaN           NaN          NaN    8445550
# 15                        NaN           NaN          NaN    8445550
# 18                     325:02           0.0       2353.0    8445550
# 21                     210:29           0.0       1667.0    8445550
# 23                     304:24           0.0       2156.0    8445550
# 24                     209:00           0.0       1572.0    8445550
# 25                      52:25           0.0        445.0    8445550
# 26                     284:23           0.0       2472.0    8445550
# 28                     317:08          33.0       2749.0    8445550
# 29                     225:39           0.0       2531.0    8445550
# 30                     349:17         175.0       2708.0    8445550
# 32                     272:55         127.0       2232.0    8445550
# 33                     246:32         143.0       1933.0    8445550
# 34                     182:56         114.0       1960.0    8445550
# 35                     201:52         114.0       1990.0    8445550
#
#     first_name  last_name  position_code
# 4          Rob      Blake              D
# 6          Rob      Blake              D
# 8          Rob      Blake              D
# 9          Rob      Blake              D
# 10         Rob      Blake              D
# 12         Rob      Blake              D
# 13         Rob      Blake              D
# 15         Rob      Blake              D
# 18         Rob      Blake              D
# 21         Rob      Blake              D
# 23         Rob      Blake              D
# 24         Rob      Blake              D
# 25         Rob      Blake              D
# 26         Rob      Blake              D
# 28         Rob      Blake              D
# 29         Rob      Blake              D
# 30         Rob      Blake              D
# 32         Rob      Blake              D
# 33         Rob      Blake              D
# 34         Rob      Blake              D
# 35         Rob      Blake              D
#
# [21 rows x 35 columns]
#       season  sequenceNumber  stat_assists  stat_goals  stat_pim  stat_games  \
# 5   19881989               1             0           0         0           9
# 7   19891990               1             3           3        25          28
# 9   19901991               1             2           0         0           3
# 11  19911992               1             1           0         0           3
#
#    stat_penaltyMinutes  stat_points         team_name        team_link  ...  \
# 5                    0            0  New York Rangers  /api/v1/teams/3  ...
# 7                   25            6  New York Rangers  /api/v1/teams/3  ...
# 9                    0            2  New York Rangers  /api/v1/teams/3  ...
# 11                   0            1  New York Rangers  /api/v1/teams/3  ...
#
#    stat_shotPct stat_gameWinningGoals  stat_overTimeGoals  \
# 5           0.0                   0.0                 0.0
# 7          15.0                   1.0                 0.0
# 9           0.0                   0.0                 0.0
# 11          0.0                   0.0                 0.0
#
#     stat_shortHandedGoals  stat_shortHandedPoints  stat_plusMinus  player_id  \
# 5                     0.0                     0.0             2.0    8445555
# 7                     0.0                     0.0            -8.0    8445555
# 9                     0.0                     0.0             3.0    8445555
# 11                    0.0                     0.0             1.0    8445555
#
#     first_name  last_name  position_code
# 5         Jeff  Bloemberg              D
# 7         Jeff  Bloemberg              D
# 9         Jeff  Bloemberg              D
# 11        Jeff  Bloemberg              D
#
# [4 rows x 27 columns]
#       season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 12  19811982               1            NaN            11           1
# 14  19821983               1            NaN            17           1
# 16  19831984               1            NaN            19           1
# 17  19841985               1            NaN             4           1
# 20  19861987               1            NaN             2           0
#
#     stat_pim  stat_games stat_powerPlayTimeOnIce stat_evenTimeOnIce  \
# 12        62          44                     NaN                NaN
# 14        67          61                     NaN                NaN
# 16        84          65                     NaN                NaN
# 17        51          53                     NaN                NaN
# 20        29          20                     NaN                NaN
#
#    stat_penaltyMinutes  ... stat_gameWinningGoals  stat_overTimeGoals  \
# 12                  62  ...                   0.0                 0.0
# 14                  67  ...                   1.0                 0.0
# 16                  84  ...                   0.0                 0.0
# 17                  51  ...                   0.0                 0.0
# 20                  29  ...                   0.0                 0.0
#
#     stat_shortHandedGoals  stat_shortHandedPoints stat_plusMinus  \
# 12                    0.0                     0.0          -17.0
# 14                    0.0                     0.0           17.0
# 16                    0.0                     0.0           17.0
# 17                    0.0                     0.0           10.0
# 20                    0.0                     0.0           -3.0
#
#    stat_faceOffPct player_id first_name  last_name  position_code
# 12             NaN   8445557       Timo  Blomqvist              D
# 14             NaN   8445557       Timo  Blomqvist              D
# 16             NaN   8445557       Timo  Blomqvist              D
# 17             NaN   8445557       Timo  Blomqvist              D
# 20             NaN   8445557       Timo  Blomqvist              D
#
# [5 rows x 33 columns]
#       season  sequenceNumber  stat_assists  stat_goals  stat_pim  stat_games  \
# 7   19751976               1            31          25        29          74
# 8   19761977               1            40          28        32          78
# 9   19771978               1            38          25        33          80
# 10  19781979               1            10           5        16          56
# 12  19791980               1             6          12        54          33
# 13  19801981               1             0           1         4           3
# 17  19821983               1             0           0         2           2
#
#    stat_penaltyMinutes  stat_points  team_id          team_name  ...  \
# 7                   29           56     23.0  Vancouver Canucks  ...
# 8                   32           68     23.0  Vancouver Canucks  ...
# 9                   33           63     23.0  Vancouver Canucks  ...
# 10                  16           15     23.0  Vancouver Canucks  ...
# 12                  54           18     23.0  Vancouver Canucks  ...
# 13                   4            1     23.0  Vancouver Canucks  ...
# 17                   2            0     26.0  Los Angeles Kings  ...
#
#    stat_shotPct  stat_gameWinningGoals stat_overTimeGoals  \
# 7         11.79                    3.0                0.0
# 8         14.14                    5.0                0.0
# 9         10.50                    2.0                0.0
# 10         5.49                    1.0                0.0
# 12        14.63                    0.0                0.0
# 13        11.11                    0.0                0.0
# 17         0.00                    0.0                0.0
#
#    stat_shortHandedGoals  stat_shortHandedPoints  stat_plusMinus  player_id  \
# 7                    0.0                     0.0            -4.0    8445558
# 8                    0.0                     0.0             0.0    8445558
# 9                    0.0                     0.0           -32.0    8445558
# 10                   0.0                     0.0           -28.0    8445558
# 12                   0.0                     0.0             6.0    8445558
# 13                   0.0                     0.0            -1.0    8445558
# 17                   0.0                     0.0            -3.0    8445558
#
#     first_name  last_name  position_code
# 7         Rick     Blight              R
# 8         Rick     Blight              R
# 9         Rick     Blight              R
# 10        Rick     Blight              R
# 12        Rick     Blight              R
# 13        Rick     Blight              R
# 17        Rick     Blight              R
#
# [7 rows x 27 columns]
#       season  sequenceNumber stat_timeOnIce            team_name  \
# 6   19821983               1            NaN      Edmonton Oilers
# 8   19831984               1            NaN      Edmonton Oilers
# 9   19831984               2            NaN        Boston Bruins
# 11  19841985               1            NaN        Boston Bruins
# 12  19851986               1            NaN        Boston Bruins
# 14  19861987               1            NaN  Washington Capitals
# 15  19871988               1            NaN        Boston Bruins
# 17  19881989               1            NaN    Detroit Red Wings
# 19  19891990               1            NaN        Boston Bruins
#
#            team_link             league_name         league_link  \
# 6   /api/v1/teams/22  National Hockey League  /api/v1/league/133
# 8   /api/v1/teams/22  National Hockey League  /api/v1/league/133
# 9    /api/v1/teams/6  National Hockey League  /api/v1/league/133
# 11   /api/v1/teams/6  National Hockey League  /api/v1/league/133
# 12   /api/v1/teams/6  National Hockey League  /api/v1/league/133
# 14  /api/v1/teams/15  National Hockey League  /api/v1/league/133
# 15   /api/v1/teams/6  National Hockey League  /api/v1/league/133
# 17  /api/v1/teams/17  National Hockey League  /api/v1/league/133
# 19   /api/v1/teams/6  National Hockey League  /api/v1/league/133
#
#     stat_assists  stat_goals  stat_pim  ...  stat_gameWinningGoals  \
# 6            3.0         0.0      24.0  ...                    0.0
# 8            1.0         0.0       2.0  ...                    0.0
# 9            1.0         1.0      30.0  ...                    1.0
# 11          13.0         3.0     263.0  ...                    0.0
# 12           7.0         1.0      80.0  ...                    0.0
# 14           8.0         2.0     133.0  ...                    0.0
# 15           1.0         0.0      70.0  ...                    0.0
# 17           0.0         0.0       8.0  ...                    0.0
# 19           0.0         0.0       0.0  ...                    0.0
#
#    stat_overTimeGoals  stat_shortHandedGoals  stat_shortHandedPoints  \
# 6                 0.0                    0.0                     0.0
# 8                 0.0                    0.0                     0.0
# 9                 0.0                    0.0                     0.0
# 11                0.0                    0.0                     0.0
# 12                0.0                    0.0                     0.0
# 14                0.0                    0.0                     0.0
# 15                0.0                    0.0                     0.0
# 17                0.0                    0.0                     0.0
# 19                0.0                    0.0                     0.0
#
#     stat_plusMinus  stat_shotPct  player_id  first_name  last_name  \
# 6              2.0           NaN    8445559        John       Blum
# 8              0.0          0.00    8445559        John       Blum
# 9              5.0         11.11    8445559        John       Blum
# 11             0.0          8.33    8445559        John       Blum
# 12             8.0          2.94    8445559        John       Blum
# 14             1.0          6.25    8445559        John       Blum
# 15            -5.0          0.00    8445559        John       Blum
# 17            -2.0          0.00    8445559        John       Blum
# 19            -1.0          0.00    8445559        John       Blum
#
#     position_code
# 6               D
# 8               D
# 9               D
# 11              D
# 12              D
# 14              D
# 15              D
# 17              D
# 19              D
#
# [9 rows x 28 columns]

# %% [markdown]
# Next I needed to add a second conditional statement on the `stats` response to evaluate if a player has played at least 200 games.

# %%
# Add conditional evaluating number of games played by the current player
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8445550, 8445560)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code == 404:
        pass
    else:
        bio = json.loads(response.content)['people']
        player = (pd.json_normalize(bio))
        
        if player['primaryPosition.code'][0] == 'G':
            pass
        else:
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            content = json.loads(response.content)['stats']
            splits = content[0]['splits']
            
            df_splits = (pd.json_normalize(splits, sep = "_" )
                         .query('league_name == "National Hockey League"')
                        )
            
            if df_splits.shape[0] < 3:
                pass
            else:
                df_splits['player_id'] = player['id'][0]
                df_splits['first_name'] = player['firstName'][0]
                df_splits['last_name'] = player['lastName'][0]
                df_splits['position_code'] = player['primaryPosition.code'][0]
                
                # create a new DF that stores the total games played by the current player
                total_games = df_splits.groupby(['player_id', 'first_name', 'last_name'])['stat_games'].sum().reset_index()
                
                # evaluate if current player has played more than 200 games, if so pass to filtered DF
                filtered_total_games = total_games[total_games['stat_games'] > 200]
                
                # if the the filtered DF has an entry in it, continue
                if not filtered_total_games.empty:
                    # print the filtered DF
                    print(filtered_total_games)
                else:
                    pass
# Out:
#    player_id first_name last_name  stat_games
# 0    8445550        Rob     Blake        1270
#    player_id first_name  last_name  stat_games
# 0    8445557       Timo  Blomqvist         243
#    player_id first_name last_name  stat_games
# 0    8445558       Rick    Blight         326
#    player_id first_name last_name  stat_games
# 0    8445559       John      Blum       250.0

# %%
# Sanity check - print response codes & total games played for each ID 
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8445550, 8445560)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    # PRINT 1
    print(response)
    
    if response.status_code == 404:
        pass
    else:
        bio = json.loads(response.content)['people']
        player = (pd.json_normalize(bio))
        
        # PRINT 2
        print(player['primaryPosition.code'][0])
        
        if player['primaryPosition.code'][0] == 'G':
            pass
        else:
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            content = json.loads(response.content)['stats']
            splits = content[0]['splits']
            
            df_splits = (pd.json_normalize(splits, sep = "_" )
                         .query('league_name == "National Hockey League"')
                        )
            
            # PRINT 3
            print(df_splits.shape[0])
            
            if df_splits.shape[0] < 3:
                pass
            else:
                df_splits['player_id'] = player['id'][0]
                df_splits['first_name'] = player['firstName'][0]
                df_splits['last_name'] = player['lastName'][0]
                df_splits['position_code'] = player['primaryPosition.code'][0]
                total_games = df_splits.groupby(['player_id', 'first_name', 'last_name'])['stat_games'].sum().reset_index()
                filtered_total_games = total_games[total_games['stat_games'] > 200]
                
                # PRINT 4
                print(total_games)
                
                if not filtered_total_games.empty:
                    print('GOOD PLAYER!')
                else:
                    pass
# Out:
# <Response [200]>
# D
# 21
#    player_id first_name last_name  stat_games
# 0    8445550        Rob     Blake        1270
# GOOD PLAYER!
# <Response [200]>
# G
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [200]>
# D
# 4
#    player_id first_name  last_name  stat_games
# 0    8445555       Jeff  Bloemberg          43
# <Response [404]>
# <Response [200]>
# D
# 5
#    player_id first_name  last_name  stat_games
# 0    8445557       Timo  Blomqvist         243
# GOOD PLAYER!
# <Response [200]>
# R
# 7
#    player_id first_name last_name  stat_games
# 0    8445558       Rick    Blight         326
# GOOD PLAYER!
# <Response [200]>
# D
# 9
#    player_id first_name last_name  stat_games
# 0    8445559       John      Blum       250.0
# GOOD PLAYER!

# %% [markdown]
# Reading the output of the above code, the conditionals are functioning as designed.

# %% [markdown]
# ### Implementing DataFrame Concatenation
#
# The last step here is to implement code that will take the DataFrame of a player meeting all conditions, and concatenate it to a main a main DataFrame of all such players.  I tested the code over 20 player IDs, and returned the DataFrame.
#
# During this step, another error response code was encountered (code 500), in the case where a player has an NHL profile, but has no stats associated with it.

# %%
# Final piece of code to test functionality - 20 player IDs
main_df_test = pd.DataFrame()
base_url = 'https://statsapi.web.nhl.com/api/v1/people/'
range1 = range(8445550, 8445570)

for num in range1:
    people_url = f'{base_url}{num}'
    response = requests.get(people_url)
    
    if response.status_code != 404:
        suggestions = json.loads(response.content)['people']
        player = (pd.json_normalize(suggestions))
        
        if player['primaryPosition.code'][0] != 'G':
            stats_url = f'{base_url}{num}/stats/?stats=yearByYear'
            response = requests.get(stats_url)
            
            # evaluate response code, pass if 500
            if response.status_code != 500:
                content = json.loads(response.content)['stats']
                splits = content[0]['splits']
                
                df_splits = (pd.json_normalize(splits, sep = "_" )
                             .query('league_name == "National Hockey League"')
                            )
                            
                if df_splits.shape[0] >= 3:
                    df_splits['player_id'] = player['id'][0]
                    df_splits['first_name'] = player['firstName'][0]
                    df_splits['last_name'] = player['lastName'][0]
                    df_splits['position_code'] = player['primaryPosition.code'][0]
                    df_splits['stat_games'] = df_splits['stat_games'].astype(int)
                    total_games = df_splits.groupby(['player_id', 'first_name', 'last_name', 'position_code'])['stat_games'].sum().reset_index()
                    filtered_total_games = total_games[total_games['stat_games'] > 200]
                    
                    if not filtered_total_games.empty:
                        df_splits['season_start_yr'] = [x[0:4] for x in df_splits['season']]
                        df_splits['season_start_dt'] =  [datetime.strptime(x + '0930', "%Y%m%d") for x in df_splits['season_start_yr']] 
                        df_splits['season_end'] = [x[4:8] for x in df_splits['season']]
                        
                        df_splits['weight'] = player['weight'][0]
                        df_splits['height'] = player['height'][0]
                        df_splits['shot_dir'] = player['shootsCatches'][0]
                        df_splits['birth_date'] = pd.to_datetime(player['birthDate'][0])
                        df_splits['age'] = (np.floor((df_splits['season_start_dt'] - df_splits['birth_date'])/ np.timedelta64(1,'Y') ))
                        df_splits['age'] = df_splits['age'].astype(int)
                        df_splits['position_name'] = player['primaryPosition.name'][0]
                        df_splits['position_type'] = player['primaryPosition.type'][0]
                        df_splits['birth_country'] = player['birthCountry'][0]
                        df_splits['nationality'] = player['nationality'][0]
                        
                        # concatenate the DF for the current player, to the main DF
                        main_df_test = pd.concat([main_df_test, df_splits], sort=False).reset_index(drop=True)
                    else:
                        pass        
                else:
                    pass
            else:
                pass
        else:
            pass
    else:
        pass

# %%
# show the resulting DataFrame
main_df_test
# Out:
#       season  sequenceNumber stat_timeOnIce  stat_assists  stat_goals  \
# 0   19891990               1            NaN           0.0         0.0
# 1   19901991               1            NaN          34.0        12.0
# 2   19911992               1            NaN          13.0         7.0
# 3   19921993               1            NaN          43.0        16.0
# 4   19931994               1            NaN          48.0        20.0
# ..       ...             ...            ...           ...         ...
# 56  19961997               1            NaN          15.0         1.0
# 57  19971998               1         625:33           6.0         4.0
# 58  19971998               2         831:41           5.0         5.0
# 59  19981999               1        1264:08          11.0         3.0
# 60  19992000               1         211:45           1.0         0.0
#
#     stat_pim  stat_games stat_penaltyMinutes  stat_points          team_name  \
# 0        4.0           4                   4          0.0  Los Angeles Kings
# 1      125.0          75                 125         46.0  Los Angeles Kings
# 2      102.0          57                 102         20.0  Los Angeles Kings
# 3      152.0          76                 152         59.0  Los Angeles Kings
# 4      137.0          84                 137         68.0  Los Angeles Kings
# ..       ...         ...                 ...          ...                ...
# 56      64.0          81                  64         16.0    San Jose Sharks
# 57      32.0          28                  32         10.0    San Jose Sharks
# 58      25.0          49                  25         10.0  New Jersey Devils
# 59      34.0          65                  34         14.0  Los Angeles Kings
# 60       4.0          13                   4          1.0  Vancouver Canucks
#
#     ... season_end weight height  shot_dir  birth_date  age  position_name  \
# 0   ...       1990    220  6' 4"         R  1969-12-10   19     Defenseman
# 1   ...       1991    220  6' 4"         R  1969-12-10   20     Defenseman
# 2   ...       1992    220  6' 4"         R  1969-12-10   21     Defenseman
# 3   ...       1993    220  6' 4"         R  1969-12-10   22     Defenseman
# 4   ...       1994    220  6' 4"         R  1969-12-10   23     Defenseman
# ..  ...        ...    ...    ...       ...         ...  ...            ...
# 56  ...       1997    210  6' 2"         L  1966-06-18   30     Defenseman
# 57  ...       1998    210  6' 2"         L  1966-06-18   31     Defenseman
# 58  ...       1998    210  6' 2"         L  1966-06-18   31     Defenseman
# 59  ...       1999    210  6' 2"         L  1966-06-18   32     Defenseman
# 60  ...       2000    210  6' 2"         L  1966-06-18   33     Defenseman
#
#     position_type  birth_country  nationality
# 0      Defenseman            CAN          CAN
# 1      Defenseman            CAN          CAN
# 2      Defenseman            CAN          CAN
# 3      Defenseman            CAN          CAN
# 4      Defenseman            CAN          CAN
# ..            ...            ...          ...
# 56     Defenseman            CAN          CAN
# 57     Defenseman            CAN          CAN
# 58     Defenseman            CAN          CAN
# 59     Defenseman            CAN          CAN
# 60     Defenseman            CAN          CAN
#
# [61 rows x 47 columns]
